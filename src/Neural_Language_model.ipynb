# %%
import re
import json

class WordPieceTokenizer:
    
    """
    Initialisation: 
    1. Create a dictionary to store vocab and another to store freq
    2. Define vocab size
    """
    def __init__(self, vocab_size : int):
        
        self.vocab = []
        self.word_freq = {}
        self.vocab_size = vocab_size
    
    """
    Preprocessing: 
    1. Convert to lower case
    2. Split into words & remove spaces
    3. Remove numbers & non-alphabetic chars like ",", ".", "!" etc. 
    4. Returns an array of strings
    """
    def preprocess_data(self, text: str):
        
        text = text.lower() 
        text = re.sub(r"[^a-zA-Z\s]", "", text) #replacing characters using RegEx
        return text.split()
    
    """
    Vocab Construction: 
    1. Preprocess the data and store in dict the frequency of every word/token
    2. Create alphabets from the  by splitting each word into letters
    3. Create splits for every word i.e. storing letters of each word in a dictionary
    4. 
    """
    def construct_vocabulary(self, corpus: list):
        
        # we get corpus as a list of sentences
        # preprocess the list and store word frequencies
        for sentence in corpus:
            tokens = self.preprocess_data(sentence)
            
            for token in tokens:
                self.word_freq[token] = self.word_freq.get(token, 0) + 1
                
        # create an initial vocabulary and splits for every word
        initial_vocabulary = [] #unique morphemes stored
        splits = {}
        for word in self.word_freq.keys():
            if word[0] not in initial_vocabulary:
                initial_vocabulary.append(word[0])
            splits[word] = []
            splits[word].append(word[0])
            
            for remaining_letter in word[1:]:
                if f"##{remaining_letter}" not in initial_vocabulary:
                    initial_vocabulary.append(f"##{remaining_letter}")
                splits[word].append(f"##{remaining_letter}")
            
        initial_vocabulary.sort()
        
        self.vocab = ["[PAD]", "[UNK]"] + initial_vocabulary.copy() # adding two special tokens to vocab
        
        # compute scores for pairs
        # merge pair
        # continue until desired vocab size is reached
        while len(self.vocab) < self.vocab_size:
            
            # calculate the scores for every possible pair in a given words' split
            scores = self.compute_all_pair_scores(splits) # returns a dictionary => pair (tuple) : score (float)
            best_pair, max_score = (), -1
            for pair, score in scores.items():
                if max_score == -1 or max_score < score:
                    best_pair = pair
                    max_score = score
             
            # merge the best pair selected in all the splits and add the merged pair to vocab   
            splits = self.merge_best_pair(best_pair[0], best_pair[1], splits)
            
            merged_pair = ""
            if best_pair[1].startswith("##") :
                merged_pair = best_pair[0] + best_pair[1][2:]
            else :
                merged_pair = best_pair[0] + best_pair[1]
                
            self.vocab.append(merged_pair)
        
        self.save_vocabulary()
            
    """
        Tokenization Process:  
        1. We preprocess the input text to clean and normalize it.  
        2. We tokenize each word into subword units using the `subword_tokenise` method.  
        3. We flatten the list of subword tokens to get a single sequence.  
        4. Finally, we return the complete list of subword tokens.  
    """
    def tokenize(self, text: str):
        processed_text = self.preprocess_data(text) 
        
        subword_tokens = []  
        for word in processed_text:  
            subword_tokens.append(self.subword_tokenise(word))  
            
        flattened_tokens = []
        for tokens in subword_tokens:
            flattened_tokens.extend(tokens)   
            
        return flattened_tokens

    
    
   ####----------------------##____________Helper Methods____________##----------------------####
    
    def save_vocabulary(self):
        vocab_file = f"vocabulary_41.txt"
        with open(vocab_file, "w") as f:
            for token in self.vocab:
                f.write(f"{token}\n")
    
    
    """
    Pair Score Computation:  
    1. We count the frequency of individual tokens and adjacent token pairs from word splits.  
    2. Then store token frequencies in `letter_freq_dict` and pair frequencies in `pair_freq_dict`.  
    3. Compute the score for each token pair using their frequency and individual token frequencies.  
    4. Return the computed scores for determining merge priorities in tokenization.  
    """
    def compute_all_pair_scores(self, splits):
        letter_freq_dict = {}
        pair_freq_dict = {}
        
        #cnt the occurrences
        for word, cnt in self.word_freq.items():
            
            split = splits[word]
            for token in split:
                letter_freq_dict[token] = letter_freq_dict.get(token, 0) + cnt
            
            if len(split) == 1 :
                continue
            else: 
                for i in range(len(split)-1):
                    pair = (split[i], split[i+1]) 
                    pair_freq_dict[pair] = pair_freq_dict.get(pair, 0) + cnt
                    
        scores = {}
        #calc the score
        for pair, freq in pair_freq_dict.items(): 
            score = freq / (letter_freq_dict[pair[0]] * letter_freq_dict[pair[1]])
            scores[pair] = score
                
        return scores
    
    
    """
    Best Pair Merging:  
    1. We iterate over each word and look for occurrences of the given token pair (a, b).  
    2. If we find the pair, we merge it into a single token and update the word’s split.  
    3. We ensure the updated split is stored back, allowing further merges if needed.  
    4. Finally, we return the modified splits with the merged tokens.  
    """
    def merge_best_pair(self, x, y, splits):
        for word in self.word_freq:
            split = splits[word]
            i = 0
            # continue until we've checked all adjacent pairs in the split.
            while i < len(split) - 1:
                if split[i] == x and split[i + 1] == y: 
                    if y.startswith("##"):
                        merge = x + y[2:]
                    else:
                        merge = x + y
                    split = split[:i] + [merge] + split[i + 2:]
                    
                    # update the split back in the dictionary.
                    splits[word] = split
                    # do not increment i, in case the new merged token can merge further.
                    # break
                else:
                    i += 1 
                    
            splits[word] = split

        return splits


    """
    Subword Tokenization:  
    1. We iteratively extract the longest valid prefix from the word that exists in our vocabulary.  
    2. If no valid prefix is found, we return the "[UNK]" token.  
    3. We append the matched prefix to the token list and remove it from the word.  
    4. If any part of the word remains, we prepend "##" to indicate it’s a subword and continue.  
    """
    def subword_tokenise(self, word):
        tokens = [] 
        # keep going until word is not empty
        while word:
            prefix = None 
            for i in range(len(word), 0, -1):
                checkWord = word[:i]
                if checkWord in self.vocab:
                    prefix = checkWord
                    break  # found longest valid prefix
            
            # no valid prefix is found -> return the unk token
            if prefix is None:
                return ["[UNK]"]
            else:
                tokens.append(prefix)
            
            # Remove the matched prefix from the word
            word = word[len(prefix):]
            if word:
                word = f"##{word}"
        
        return tokens

####----------------------####----------------------####----------------------####----------------------####----------------------####

def make_vocab_and_tokenize(vocab_size):
    corpus = []
    with open("corpus.txt", 'r') as file:
        text = file.read()
        sentences = text.split('\n')
        for sentence in sentences: 
            sentence = sentence.strip()
            if sentence:
                corpus.append(sentence)

    # print(corpus)
    tokenizer = WordPieceTokenizer(vocab_size)

    tokenizer.construct_vocabulary(corpus)
    vocab = tokenizer.vocab 

    input_json_path = 'sample_test.json'  
    output_json_path = 'tokenized_41.json' 

    tokenized_data = {}
    with open("corpus.txt", 'r') as file:
        text = file.read()
        sentences = text.split('\n')
        sentence_id = 0
        for sentence in sentences: 
            sentence = sentence.strip() 
            if sentence:
                tokens = tokenizer.tokenize(sentence)
                tokenized_data[sentence_id] = tokens
                sentence_id += 1

    # Write the tokenized data to the output JSON file
    with open(output_json_path, 'w') as f:
        json.dump(tokenized_data, f, indent=4)

if __name__ == "__main__":
    corpus = []
    with open("corpus.txt", 'r') as file:
        text = file.read()
        sentences = text.split()
        for sentence in sentences:
            sentence = sentence.strip()
            if sentence:
                corpus.append(sentence)

    tokenizer = WordPieceTokenizer(vocab_size=14000)

    tokenizer.construct_vocabulary(corpus)
    vocab = tokenizer.vocab

    output_json_path = 'tokenized_data.json'  # Path to save tokenized output

    # Prepare a dictionary to store the tokenized sentences
    tokenized_data = {}
    with open("corpus.txt", 'r') as file:
        text = file.read()
        sentences = text.split('\n')
        sentence_id = 0
        for sentence in sentences:
            sentence = sentence.strip()
            if sentence:
                tokens = tokenizer.tokenize(sentence)
                tokenized_data[sentence_id] = tokens
                sentence_id += 1

    # Write the tokenized data to the output JSON file
    with open(output_json_path, 'w') as f:
        json.dump(tokenized_data, f, indent=4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 268
#     264             corpus.append(sentence)
#     266 tokenizer = WordPieceTokenizer(vocab_size=14000)
# --> 268 tokenizer.construct_vocabulary(corpus)
#     269 vocab = tokenizer.vocab
#     271 output_json_path = 'tokenized_data.json'  # Path to save tokenized output
#
# Cell In[7], line 71, in WordPieceTokenizer.construct_vocabulary(self, corpus)
#      65 # compute scores for pairs
#      66 # merge pair
#      67 # continue until desired vocab size is reached
#      68 while len(self.vocab) < self.vocab_size:
#      69
#      70     # calculate the scores for every possible pair in a given words' split
# ---> 71     scores = self.compute_all_pair_scores(splits) # returns a dictionary => pair (tuple) : score (float)
#      72     best_pair, max_score = (), -1
#      73     for pair, score in scores.items():
#
# Cell In[7], line 145, in WordPieceTokenizer.compute_all_pair_scores(self, splits)
#     143         for i in range(len(split)-1):
#     144             pair = (split[i], split[i+1])
# --> 145             pair_freq_dict[pair] = pair_freq_dict.get(pair, 0) + cnt
#     147 scores = {}
#     148 #calc the score
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
import json
from tqdm import tqdm
import matplotlib.pyplot as plt
import torch.optim as optim

from sklearn.metrics.pairwise import cosine_similarity


vocabulary_size = 14000
context_window = 2
embedding_dim = 400
batch_size = 1024
epochs = 25
lr = 0.001
dropout_rate = 0.3
word_index_mapping, index_word_mapping = {}, {}
train_dataloader = []
val_dataloader = []

class Word2VecDataset(Dataset):
    def __init__(self, corpus):
        self.preprocessed_data = []
        self.corpus = corpus

    def __len__(self):
        return len(self.preprocessed_data)

    def __getitem__(self, index):
        target, context = self.preprocessed_data[index]
        context_tensor = torch.tensor(context, dtype=torch.long)

        total_padding = 2 * context_window - len(context_tensor)

        left_padding = total_padding // 2
        right_padding = total_padding - left_padding

        context = torch.nn.functional.pad(context_tensor, (left_padding, right_padding), value=0)
        return torch.tensor(target, dtype=torch.long), context

    def preprocess_data(self, word_index_mapping):
        data = []
        for key in self.corpus:
            tokens = self.corpus[key]

            n = len(tokens)

            for i in range(0, n):
                target = tokens[i]

                # if target not in word_index_mapping:
                #     print(f"Warning: '{target}' not found in vocabulary, skipping.")
                #     continue  # Skip this word

                tokens_before_word = tokens[max(0, i - context_window):i]
                tokens_after_word = tokens[i + 1: min(n + 1, i + 1 + context_window)]

                context = tokens_before_word + tokens_after_word

                target_index = word_index_mapping[target]
                context_index = []
                for word in context:
                    if word in word_index_mapping:
                        context_index.append(word_index_mapping[word])

                if len(context_index) > 0:
                    data.append((target_index, context_index))

        self.preprocessed_data = data


class Word2VecModel(nn.Module):
    def __init__(self, vocab_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.dropout = nn.Dropout(dropout_rate)
        self.linear = nn.Linear(embedding_dim, vocab_size)

        nn.init.xavier_uniform_(self.embedding.weight)
        nn.init.xavier_uniform_(self.linear.weight)
        if self.linear.bias is not None:
            nn.init.zeros_(self.linear.bias)

    def forward(self, context):
        embedded = self.embedding(context)  # [batch_size, context_length, embedding_dim]
        aggregated = embedded.mean(dim=1)     # [batch_size, embedding_dim]
        aggregated = self.dropout(aggregated)   # Apply dropout
        out = self.linear(aggregated)           # [batch_size, vocab_size]
        return out

    def train_model(self, model, criterion, optimizer):
        loss_list, val_loss = [], []

        for _ in tqdm(range(epochs)):
            total_loss = 0
            model.train()  # enable this if we r able to implement some dropout thingy

            for target, context in train_dataloader:
                target = target.long()
                context = context.long()

                pred = model.forward(context)
                loss = criterion(pred, target)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                total_loss += loss.item()

            number_of_samples = len(train_dataloader)
            avg_loss = total_loss / number_of_samples
            loss_list.append(avg_loss)
            print(f"Epoch {_ + 1}, Loss: {avg_loss}")

            total_loss = 0
            model.eval()

            with torch.no_grad():
                for target, context in val_dataloader:
                    target = target.long()
                    context = context.long()

                    pred = model.forward(context)
                    loss = criterion(pred, target)
                    total_loss += loss.item()

            avg_val_loss = total_loss / len(val_dataloader)
            val_loss.append(avg_val_loss)

        return loss_list, val_loss

    # def get_triplets(self, model):
    #     embeddings = model.network[0].weight.data.cpu().numpy()
    #     similarities = cosine_similarity(embeddings)
    #     triplets = []
    #
    #     for item in word_index_mapping:
    #         word, index = item[0], item[1]
    #
    #         similar, triplet = [], []
    #         similar_indices = np.argsort(similarities[index])[::-1]
    #         similar_indices = similar_indices[:3]
    #
    #         for i in similar_indices:
    #             similar.append(index_word_mapping[i])
    #         del similar[index_word_mapping[index]]
    #
    #         dissimilar_index = np.argsort(similarities[idx])[0]
    #         dissimilar = index_word_mapping[dissimilar_index]
    #
    #         triplet = [word, similar, dissimilar]
    #         triplets.append(triplet)
    #
    #     for triplet in triplets:
    #         print("Word:", triplet[0])
    #         print("Similar:", triplet[1])
    #         print("Dissimilar:", triplet[2])
    #         print()
    def get_triplets(self):
        embeddings = self.embedding.weight.data.cpu().numpy()
        similarities = cosine_similarity(embeddings)

        triplets = []

        for word, index in word_index_mapping.items():
            similar = []

            similar_indices = np.argsort(similarities[index])[::-1]
            similar_indices = [i for i in similar_indices if i != index][:3]

            for i in similar_indices:
                similar.append((index_word_mapping[i], similarities[index][i]))

            dissimilar_index = np.argsort(similarities[index])[0]
            dissimilar = (index_word_mapping[dissimilar_index], similarities[index][dissimilar_index])

            triplets.append([word, similar, dissimilar])

        for triplet in triplets:
            print("Word:", triplet[0])
            print("Similar:", [(w, round(sim, 4)) for w, sim in triplet[1]])
            print("Dissimilar:", (triplet[2][0], round(triplet[2][1], 4)))
            print()

        return triplets


def get_data(vocab_size, split=0.9):
    make_vocab_and_tokenize(vocab_size)

    file_path = "tokenized_data.json"
    with open(file_path, "r", encoding="utf-8") as file:
        corpus = json.load(file)

    vocab_file_path = "vocabulary_41.txt"

    with open(vocab_file_path, "r", encoding="utf-8") as f:
        vocab = [line.strip() for line in f]

    word_index_mapping = {word: idx for idx, word in enumerate(vocab)}
    index_word_mapping = {idx: word for word, idx in word_index_mapping.items()}
    dataset = Word2VecDataset(corpus)
    dataset.preprocess_data(word_index_mapping)

    n = len(dataset)
    train = int(n * split)
    val = n - train

    train_dataset, val_dataset = random_split(dataset, [train, val])

    train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)

    return train_dataloader, val_dataloader, word_index_mapping, index_word_mapping


def plot(loss_list, val_loss):
    plt.plot(range(1, epochs + 1), loss_list, label="Training Loss")
    plt.plot(range(1, epochs + 1), val_loss, label="Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Training Loss")
    plt.savefig("task_2.png")
    plt.legend()
    plt.grid(visible=True)
    plt.show()

def get_triplet_for_word(self, word):
    if word not in word_index_mapping:
        print(f"Word '{word}' not found in vocabulary.")
        return None

    index = word_index_mapping[word]
    embeddings = self.embedding.weight.data.cpu().numpy()
    similarities = cosine_similarity(embeddings)

    # Get sorted indices of words based on similarity (descending order)
    similar_indices = np.argsort(similarities[index])[::-1]

    # Exclude the word itself (index = `index`)
    similar_indices = [i for i in similar_indices if i != index][:3]

    similar_words = [(index_word_mapping[i], similarities[index][i]) for i in similar_indices]

    # Find the most dissimilar word (smallest similarity score)
    dissimilar_index = np.argsort(similarities[index])[0]  # Least similar word
    dissimilar_word = index_word_mapping[dissimilar_index]
    dissimilar_similarity = similarities[index][dissimilar_index]

    # Print results
    print(f"Word: {word}")
    print("Similar Words (with Cosine Similarity):")
    for sim_word, sim_value in similar_words:
        print(f"  {sim_word}: {sim_value:.4f}")

    print(f"Dissimilar Word: {dissimilar_word} (Cosine Similarity: {dissimilar_similarity:.4f})\n")

    return word, similar_words, (dissimilar_word, dissimilar_similarity)

def run_Word2Vec(vocabulary_size_ = 14000, context_window_ = 2,embedding_dim_ = 400,batch_size_ = 1024,epochs_ = 50,lr_ = 0.001, dropout_rate_ = 0.3):

    global train_dataloader, val_dataloader, word_index_mapping, index_word_mapping, vocabulary_size, context_window, embedding_dim, batch_size, epochs, lr, dropout_rate

    vocabulary_size = vocabulary_size_
    context_window = context_window_
    embedding_dim = embedding_dim_
    batch_size = batch_size_
    epochs = epochs_
    lr = lr_

    train_dataloader, val_dataloader, word_index_mapping, index_word_mapping = get_data(vocabulary_size)

    print("Loaded Data")

    model = Word2VecModel(vocabulary_size)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    print("Training...")

    loss_list, val_loss = model.train_model(model, criterion, optimizer)
    plot(loss_list, val_loss)

    torch.save(model.state_dict(), "word2vec_checkpoint.pth")

    model.get_triplets()

    get_triplet_for_word(model, "is")

if __name__ == "__main__":
    run_Word2Vec( vocabulary_size_= vocabulary_size, context_window_= context_window, embedding_dim_= embedding_dim, batch_size_= batch_size, epochs_= epochs, lr_= lr, dropout_rate_=dropout_rate)
# Out:
# Loaded Data
# Training...
#   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch 1, Loss: 9.28099502216686
#   4%|▍         | 1/25 [00:30<12:22, 30.94s/it]
# Epoch 2, Loss: 7.331638997251337
#   8%|▊         | 2/25 [00:55<10:19, 26.95s/it]
# Epoch 3, Loss: 6.166259158741344
#  12%|█▏        | 3/25 [01:25<10:30, 28.64s/it]
# Epoch 4, Loss: 6.065875898707997
#  16%|█▌        | 4/25 [01:53<09:51, 28.17s/it]
# Epoch 5, Loss: 6.006327965042808
#  20%|██        | 5/25 [02:20<09:14, 27.70s/it]
# Epoch 6, Loss: 5.9498256119814785
#  24%|██▍       | 6/25 [02:59<10:04, 31.79s/it]
# Epoch 7, Loss: 5.881844498894432
#  28%|██▊       | 7/25 [03:39<10:20, 34.49s/it]
# Epoch 8, Loss: 5.8077205419540405
#  32%|███▏      | 8/25 [04:18<10:09, 35.86s/it]
# Epoch 9, Loss: 5.727537697011774
#  36%|███▌      | 9/25 [04:42<08:31, 31.98s/it]
# Epoch 10, Loss: 5.641786477782509
#  40%|████      | 10/25 [05:07<07:29, 29.99s/it]
# Epoch 11, Loss: 5.5556370995261455
#  44%|████▍     | 11/25 [05:42<07:21, 31.56s/it]
# Epoch 12, Loss: 5.463606129993092
#  48%|████▊     | 12/25 [06:20<07:15, 33.52s/it]
# Epoch 13, Loss: 5.376546176997098
#  52%|█████▏    | 13/25 [07:11<07:45, 38.78s/it]
# Epoch 14, Loss: 5.2880587144331495
#  56%|█████▌    | 14/25 [07:47<06:56, 37.90s/it]
# Epoch 15, Loss: 5.20204531062733
#  60%|██████    | 15/25 [08:24<06:15, 37.53s/it]
# Epoch 16, Loss: 5.112974567846819
#  64%|██████▍   | 16/25 [08:56<05:24, 36.02s/it]
# Epoch 17, Loss: 5.028031815182079
#  68%|██████▊   | 17/25 [09:36<04:57, 37.23s/it]
# Epoch 18, Loss: 4.942655064842918
#  72%|███████▏  | 18/25 [10:21<04:36, 39.47s/it]
# Epoch 19, Loss: 4.856700398705223
#  76%|███████▌  | 19/25 [11:08<04:09, 41.65s/it]
# Epoch 20, Loss: 4.77400681105527
#  80%|████████  | 20/25 [11:56<03:38, 43.71s/it]
# Epoch 21, Loss: 4.684202432632446
#  84%|████████▍ | 21/25 [12:43<02:58, 44.73s/it]
# Epoch 22, Loss: 4.599158720536665
#  88%|████████▊ | 22/25 [13:25<02:11, 43.90s/it]
# Epoch 23, Loss: 4.512354135513306
#  92%|█████████▏| 23/25 [14:10<01:28, 44.27s/it]
# Epoch 24, Loss: 4.429643457586115
#  96%|█████████▌| 24/25 [14:44<00:41, 41.06s/it]
# Epoch 25, Loss: 4.346175475554033
# 100%|██████████| 25/25 [15:16<00:00, 36.67s/it]
# Word: [PAD]
# Similar: [('thinner', 0.7706), ('neither', 0.7654), ('earning', 0.7643)]
# Dissimilar: ('kindness', -0.5182)
#
# Word: [UNK]
# Similar: [('backwa', 0.1919), ('financ', 0.1884), ('influe', 0.177)]
# Dissimilar: ('##epy', -0.1805)
#
# Word: ##a
# Similar: [('return', 0.9261), ('apathetic', 0.9147), ('talent', 0.9135)]
# Dissimilar: ('internally', -0.7095)
#
# Word: ##b
# Similar: [('whine', 0.1807), ('expre', 0.168), ('##rrational', 0.1671)]
# Dissimilar: ('crowde', -0.1816)
#
# Word: ##c
# Similar: [('##ssings', 0.1691), ('##ners', 0.1557), ('smar', 0.1518)]
# Dissimilar: ('##eaching', -0.1856)
#
# Word: ##d
# Similar: [('dr', 0.8203), ('##ar', 0.8112), ('r', 0.7857)]
# Dissimilar: ('verrrrrrrryyyy', -0.5103)
#
# Word: ##e
# Similar: [('marriages', 0.8706), ('unfaithful', 0.8328), ('julie', 0.786)]
# Dissimilar: ('exhibit', -0.4142)
#
# Word: ##f
# Similar: [('cam', 0.1783), ('heartbroke', 0.1756), ('complica', 0.165)]
# Dissimilar: ('machin', -0.1955)
#
# Word: ##g
# Similar: [('s', 0.6513), ('chiangmai', 0.6347), ('##ss', 0.6214)]
# Dissimilar: ('marginalised', -0.3757)
#
# Word: ##h
# Similar: [('stripped', 0.5677), ('seal', 0.5532), ('employer', 0.5494)]
# Dissimilar: ('yall', -0.3341)
#
# Word: ##i
# Similar: [('sterile', 0.1877), ('##espair', 0.1738), ('thinne', 0.168)]
# Dissimilar: ('cupca', -0.1842)
#
# Word: ##j
# Similar: [('suffoc', 0.192), ('opposi', 0.1832), ('racis', 0.1631)]
# Dissimilar: ('##rink', -0.1881)
#
# Word: ##k
# Similar: [('reaffirme', 0.2329), ('trimeste', 0.1972), ('##lamourous', 0.1934)]
# Dissimilar: ('overw', -0.1933)
#
# Word: ##l
# Similar: [('##at', 0.8659), ('##ss', 0.8606), ('r', 0.8358)]
# Dissimilar: ('verrrrrrrryyyy', -0.4674)
#
# Word: ##m
# Similar: [('##changing', 0.1802), ('##clut', 0.1782), ('flia', 0.1743)]
# Dissimilar: ('contrar', -0.1836)
#
# Word: ##n
# Similar: [('couldve', 0.8169), ('ive', 0.7548), ('weve', 0.7496)]
# Dissimilar: ('frail', -0.4137)
#
# Word: ##o
# Similar: [('unsuccessful', 0.1793), ('swings', 0.1775), ('spinning', 0.1743)]
# Dissimilar: ('##ision', -0.2229)
#
# Word: ##p
# Similar: [('##mpora', 0.177), ('##easonal', 0.1645), ('cha', 0.1636)]
# Dissimilar: ('margina', -0.2089)
#
# Word: ##q
# Similar: [('not', 0.1927), ('californ', 0.1735), ('##rwi', 0.1708)]
# Dissimilar: ('claim', -0.1932)
#
# Word: ##r
# Similar: [('daycare', 0.8298), ('carrry', 0.8278), ('mixed', 0.7852)]
# Dissimilar: ('vapor', -0.6309)
#
# Word: ##s
# Similar: [('jimmys', 0.7659), ('bio', 0.7355), ('r', 0.7344)]
# Dissimilar: ('verrrrrrrryyyy', -0.4965)
#
# Word: ##t
# Similar: [('##at', 0.8386), ('r', 0.8343), ('##ss', 0.8336)]
# Dissimilar: ('verrrrrrrryyyy', -0.4908)
#
# Word: ##u
# Similar: [('distributio', 0.1955), ('##nsory', 0.1908), ('grows', 0.1726)]
# Dissimilar: ('cig', -0.1977)
#
# Word: ##v
# Similar: [('##littl', 0.1885), ('bitte', 0.1821), ('promo', 0.1778)]
# Dissimilar: ('overwork', -0.1788)
#
# Word: ##w
# Similar: [('pa', 0.1822), ('amplifie', 0.1815), ('##eyr', 0.1704)]
# Dissimilar: ('eithe', -0.1916)
#
# Word: ##x
# Similar: [('delighte', 0.2184), ('##work', 0.2029), ('##urround', 0.1864)]
# Dissimilar: ('incre', -0.2043)
#
# Word: ##y
# Similar: [('impractica', 0.1849), ('##ncho', 0.182), ('##odorant', 0.18)]
# Dissimilar: ('##path', -0.176)
#
# Word: ##z
# Similar: [('##est', 0.2013), ('russell', 0.2005), ('newrhin', 0.1864)]
# Dissimilar: ('tub', -0.2176)
#
# Word: a
# Similar: [('rylin', 0.7224), ('pre', 0.7137), ('nervs', 0.682)]
# Dissimilar: ('across', -0.3906)
#
# Word: b
# Similar: [('while', 0.7342), ('legend', 0.7303), ('classic', 0.7302)]
# Dissimilar: ('awards', -0.5323)
#
# Word: c
# Similar: [('choice', 0.8705), ('planner', 0.8626), ('adoring', 0.8565)]
# Dissimilar: ('internally', -0.7458)
#
# Word: d
# Similar: [('di', 0.7056), ('emergence', 0.6953), ('interest', 0.6789)]
# Dissimilar: ('vapor', -0.4548)
#
# Word: e
# Similar: [('programs', 0.7152), ('challenges', 0.6745), ('paint', 0.6683)]
# Dissimilar: ('awards', -0.5071)
#
# Word: f
# Similar: [('doesn', 0.7266), ('habitual', 0.7256), ('won', 0.7194)]
# Dissimilar: ('sweat', -0.4094)
#
# Word: g
# Similar: [('dish', 0.1832), ('submi', 0.174), ('##top', 0.1706)]
# Dissimilar: ('##call', -0.1927)
#
# Word: h
# Similar: [('##nvitation', 0.1762), ('##ecently', 0.1749), ('thrif', 0.1714)]
# Dissimilar: ('##andfath', -0.2165)
#
# Word: i
# Similar: [('they', 0.7575), ('professors', 0.7279), ('zombies', 0.7242)]
# Dissimilar: ('beside', -0.5953)
#
# Word: j
# Similar: [('picnic', 0.7623), ('glasses', 0.7579), ('classy', 0.7562)]
# Dissimilar: ('internally', -0.5374)
#
# Word: k
# Similar: [('trusty', 0.1906), ('spazz', 0.1855), ('gel', 0.181)]
# Dissimilar: ('##rday', -0.2009)
#
# Word: l
# Similar: [('##ph', 0.1893), ('##inancially', 0.1862), ('stereotyp', 0.1745)]
# Dissimilar: ('##ssons', -0.1719)
#
# Word: m
# Similar: [('jimmys', 0.8241), ('min', 0.8038), ('def', 0.7919)]
# Dissimilar: ('verrrrrrrryyyy', -0.5783)
#
# Word: n
# Similar: [('lyman', 0.8802), ('victoria', 0.8652), ('compensated', 0.8415)]
# Dissimilar: ('gently', -0.5645)
#
# Word: o
# Similar: [('skinner', 0.4057), ('circle', 0.401), ('looooong', 0.3948)]
# Dissimilar: ('sound', -0.3367)
#
# Word: p
# Similar: [('list', 0.9356), ('sit', 0.8777), ('clench', 0.875)]
# Dissimilar: ('internally', -0.7046)
#
# Word: q
# Similar: [('they', 0.6348), ('shades', 0.6265), ('tenge', 0.6124)]
# Dissimilar: ('violence', -0.4056)
#
# Word: r
# Similar: [('##ar', 0.8732), ('##ss', 0.866), ('##at', 0.862)]
# Dissimilar: ('verrrrrrrryyyy', -0.5398)
#
# Word: s
# Similar: [('forced', 0.7945), ('jimmys', 0.788), ('m', 0.7736)]
# Dissimilar: ('wh', -0.6355)
#
# Word: t
# Similar: [('problemn', 0.6706), ('carin', 0.5821), ('dont', 0.5672)]
# Dissimilar: ('greg', -0.4444)
#
# Word: u
# Similar: [('i', 0.6937), ('ryder', 0.6135), ('he', 0.6081)]
# Dissimilar: ('beside', -0.467)
#
# Word: v
# Similar: [('discom', 0.1768), ('##ssional', 0.1604), ('motivati', 0.1596)]
# Dissimilar: ('##ood', -0.2112)
#
# Word: w
# Similar: [('##ciativ', 0.179), ('##mplishing', 0.1743), ('##ely', 0.1692)]
# Dissimilar: ('flattene', -0.1982)
#
# Word: x
# Similar: [('swing', 0.7339), ('front', 0.702), ('receiving', 0.6967)]
# Dissimilar: ('hugely', -0.4374)
#
# Word: y
# Similar: [('imprint', 0.1701), ('##ecoming', 0.1677), ('##aday', 0.1655)]
# Dissimilar: ('##eagulls', -0.1877)
#
# Word: z
# Similar: [('stayviolation', 0.7649), ('pics', 0.7511), ('papermakeupstamps', 0.7495)]
# Dissimilar: ('awards', -0.5775)
#
# Word: ex
# Similar: [('##erv', 0.1822), ('lattic', 0.1755), ('cupc', 0.175)]
# Dissimilar: ('junio', -0.2007)
#
# Word: xx
# Similar: [('xelliealicex', 0.6125), ('spiral', 0.471), ('vapor', 0.4275)]
# Dissimilar: ('everybody', -0.5437)
#
# Word: ##zz
# Similar: [('endors', 0.1709), ('retireme', 0.1641), ('##europathy', 0.1633)]
# Dissimilar: ('dism', -0.1702)
#
# Word: ##qu
# Similar: [('mari', 0.1731), ('exper', 0.1698), ('##bbish', 0.1652)]
# Dissimilar: ('##obd', -0.1816)
#
# Word: bq
# Similar: [('##mot', 0.1701), ('wi', 0.1672), ('##sibil', 0.1642)]
# Dissimilar: ('remote', -0.1783)
#
# Word: bqf
# Similar: [('##sychologica', 0.2095), ('##isman', 0.2019), ('eithe', 0.1922)]
# Dissimilar: ('broth', -0.1881)
#
# Word: bqff
# Similar: [('attire', 0.9384), ('chair', 0.9353), ('faithfulness', 0.9351)]
# Dissimilar: ('internally', -0.7635)
#
# Word: qu
# Similar: [('favour', 0.2252), ('fitne', 0.2099), ('skirt', 0.1606)]
# Dissimilar: ('buys', -0.2045)
#
# Word: of
# Similar: [('listing', 0.5939), ('pulling', 0.5633), ('previous', 0.5547)]
# Dissimilar: ('what', -0.4294)
#
# Word: ev
# Similar: [('##law', 0.1852), ('##niiiiifff', 0.1829), ('##ailur', 0.1697)]
# Dissimilar: ('response', -0.1955)
#
# Word: equ
# Similar: [('feel', 0.2041), ('thes', 0.1968), ('kay', 0.1862)]
# Dissimilar: ('##noy', -0.1745)
#
# Word: exp
# Similar: [('##iv', 0.1808), ('##atl', 0.1708), ('passiona', 0.1687)]
# Dissimilar: ('##turous', -0.1829)
#
# Word: up
# Similar: [('watch', 0.5582), ('wrestling', 0.5478), ('check', 0.5432)]
# Dissimilar: ('regardless', -0.4652)
#
# Word: ju
# Similar: [('machia', 0.1873), ('marve', 0.177), ('##esult', 0.1712)]
# Dissimilar: ('##tur', -0.2017)
#
# Word: ##bj
# Similar: [('obe', 0.1892), ('tim', 0.1741), ('##rav', 0.1741)]
# Dissimilar: ('vibratio', -0.1831)
#
# Word: ##ubj
# Similar: [('hav', 0.1865), ('##tsuma', 0.183), ('facilita', 0.1749)]
# Dissimilar: ('phr', -0.2294)
#
# Word: obj
# Similar: [('discoura', 0.1799), ('subco', 0.1684), ('skeletal', 0.1665)]
# Dissimilar: ('##ad', -0.2076)
#
# Word: subj
# Similar: [('##emonstrat', 0.1686), ('translat', 0.1676), ('##ntact', 0.163)]
# Dissimilar: ('ingredie', -0.1871)
#
# Word: jus
# Similar: [('##building', 0.2387), ('curiosit', 0.1941), ('limi', 0.1791)]
# Dissimilar: ('##lls', -0.1927)
#
# Word: jum
# Similar: [('out', 0.1957), ('chocola', 0.1803), ('shiel', 0.1754)]
# Dissimilar: ('editor', -0.1816)
#
# Word: jump
# Similar: [('perform', 0.9264), ('ask', 0.909), ('stay', 0.9077)]
# Dissimilar: ('internally', -0.7895)
#
# Word: jumb
# Similar: [('appreh', 0.2186), ('##turizing', 0.1598), ('##ax', 0.1548)]
# Dissimilar: ('##sibly', -0.1968)
#
# Word: exc
# Similar: [('rainbows', 0.1872), ('thal', 0.1842), ('vapor', 0.1718)]
# Dissimilar: ('worse', -0.225)
#
# Word: ##zzy
# Similar: [('jongwoon', 0.2391), ('intellect', 0.2328), ('today', 0.1986)]
# Dissimilar: ('crosswor', -0.2018)
#
# Word: jub
# Similar: [('stroke', 0.1687), ('vort', 0.1685), ('rainbows', 0.1671)]
# Dissimilar: ('##egrity', -0.1806)
#
# Word: jumbl
# Similar: [('hohoh', 0.1935), ('master', 0.1909), ('bloke', 0.1888)]
# Dissimilar: ('sticki', -0.1836)
#
# Word: ##uzz
# Similar: [('##nk', 0.2054), ('gros', 0.1815), ('##ingernails', 0.1794)]
# Dissimilar: ('##enounc', -0.1607)
#
# Word: puzz
# Similar: [('empowere', 0.1767), ('##erg', 0.1687), ('##nhuma', 0.1642)]
# Dissimilar: ('publ', -0.2241)
#
# Word: puzzl
# Similar: [('xma', 0.1679), ('chap', 0.1595), ('opportunit', 0.1546)]
# Dissimilar: ('helpl', -0.183)
#
# Word: equa
# Similar: [('##ssary', 0.1782), ('##rknob', 0.1684), ('nefe', 0.1617)]
# Dissimilar: ('##exp', -0.1756)
#
# Word: jubi
# Similar: [('##bs', 0.2031), ('##tuc', 0.171), ('##tionabl', 0.1671)]
# Dissimilar: ('compr', -0.2026)
#
# Word: jubil
# Similar: [('revamp', 0.1707), ('fragran', 0.1651), ('war', 0.1632)]
# Dissimilar: ('##liarity', -0.1839)
#
# Word: jubila
# Similar: [('##econds', 0.1829), ('trolle', 0.1724), ('spont', 0.172)]
# Dissimilar: ('##moon', -0.1602)
#
# Word: just
# Similar: [('also', 0.677), ('didnt', 0.677), ('definitely', 0.675)]
# Dissimilar: ('internally', -0.5289)
#
# Word: ##uzzy
# Similar: [('integrated', 0.1734), ('bondmusing', 0.1697), ('previously', 0.1665)]
# Dissimilar: ('larg', -0.1893)
#
# Word: buzzy
# Similar: [('sort', 0.8391), ('tons', 0.8165), ('kind', 0.812)]
# Dissimilar: ('awards', -0.5527)
#
# Word: fuzzy
# Similar: [('exceptionally', 0.688), ('heartache', 0.6253), ('generous', 0.6222)]
# Dissimilar: ('neva', -0.3955)
#
# Word: ##izzy
# Similar: [('##nsomnia', 0.2056), ('##lant', 0.1815), ('##eg', 0.1791)]
# Dissimilar: ('appetit', -0.192)
#
# Word: dizzy
# Similar: [('flias', 0.8444), ('outrageous', 0.8438), ('goal', 0.8395)]
# Dissimilar: ('awards', -0.7741)
#
# Word: lizzy
# Similar: [('##sh', 0.8881), ('waving', 0.8504), ('condemn', 0.8322)]
# Dissimilar: ('internally', -0.6697)
#
# Word: xb
# Similar: [('##njami', 0.1875), ('ki', 0.1874), ('##mfoo', 0.179)]
# Dissimilar: ('washr', -0.1926)
#
# Word: xbl
# Similar: [('al', 0.2026), ('ebayed', 0.186), ('##nuff', 0.1801)]
# Dissimilar: ('##rward', -0.1831)
#
# Word: xbla
# Similar: [('medicine', 0.7407), ('appeared', 0.6856), ('moods', 0.6814)]
# Dissimilar: ('headaches', -0.4472)
#
# Word: th
# Similar: [('crutches', 0.8927), ('firey', 0.8363), ('flattened', 0.8185)]
# Dissimilar: ('internally', -0.631)
#
# Word: jubilan
# Similar: [('fig', 0.2068), ('wus', 0.1771), ('##evel', 0.1758)]
# Dissimilar: ('estrange', -0.1719)
#
# Word: jubilant
# Similar: [('unsafe', 0.9792), ('stare', 0.9451), ('swirling', 0.9443)]
# Dissimilar: ('awards', -0.8169)
#
# Word: my
# Similar: [('his', 0.6276), ('seizing', 0.6043), ('their', 0.5894)]
# Dissimilar: ('norma', -0.3712)
#
# Word: ov
# Similar: [('filmmake', 0.2109), ('##unching', 0.1815), ('sys', 0.172)]
# Dissimilar: ('##elfish', -0.195)
#
# Word: ##pp
# Similar: [('suits', 0.2051), ('##akingly', 0.2025), ('mrdanbair', 0.1682)]
# Dissimilar: ('##dur', -0.1969)
#
# Word: qui
# Similar: [('aba', 0.2048), ('uncomforta', 0.1649), ('completen', 0.1586)]
# Dissimilar: ('##u', -0.1712)
#
# Word: wh
# Similar: [('verrrrrrrryyyy', 0.708), ('initiation', 0.6242), ('ridiculously', 0.605)]
# Dissimilar: ('s', -0.6355)
#
# Word: quit
# Similar: [('wish', 0.9531), ('ini', 0.941), ('drove', 0.9369)]
# Dissimilar: ('internally', -0.729)
#
# Word: quic
# Similar: [('##eality', 0.1915), ('obria', 0.1802), ('##ndom', 0.1781)]
# Dissimilar: ('offend', -0.1726)
#
# Word: quick
# Similar: [('##alli', 0.2089), ('est', 0.179), ('##entury', 0.1682)]
# Dissimilar: ('##rationa', -0.1896)
#
# Word: quickl
# Similar: [('delivered', 0.1983), ('##anation', 0.1917), ('sp', 0.1731)]
# Dissimilar: ('journe', -0.1756)
#
# Word: quickly
# Similar: [('neurotic', 0.8322), ('potential', 0.8288), ('practical', 0.821)]
# Dissimilar: ('violence', -0.6061)
#
# Word: quiv
# Similar: [('##post', 0.1858), ('impos', 0.1747), ('##stal', 0.1725)]
# Dissimilar: ('destin', -0.2094)
#
# Word: ##azz
# Similar: [('handh', 0.1981), ('zoo', 0.1896), ('##essment', 0.1634)]
# Dissimilar: ('##logging', -0.2003)
#
# Word: dazz
# Similar: [('##ibi', 0.1883), ('peacefuln', 0.1822), ('casua', 0.1698)]
# Dissimilar: ('##diation', -0.22)
#
# Word: ##pazz
# Similar: [('shor', 0.1647), ('##ealm', 0.1643), ('##emons', 0.1634)]
# Dissimilar: ('courtes', -0.1752)
#
# Word: spazz
# Similar: [('##ision', 0.1895), ('resemblanc', 0.1894), ('##rida', 0.1862)]
# Dissimilar: ('##pic', -0.1932)
#
# Word: dazzl
# Similar: [('##asingly', 0.1806), ('##lationships', 0.1793), ('##llusion', 0.1731)]
# Dissimilar: ('##ams', -0.2123)
#
# Word: dazzli
# Similar: [('musc', 0.197), ('unknow', 0.1788), ('##tifi', 0.1752)]
# Dissimilar: ('pressur', -0.213)
#
# Word: ##izz
# Similar: [('##conomy', 0.1755), ('##asonabl', 0.1735), ('##strian', 0.1709)]
# Dissimilar: ('##aning', -0.182)
#
# Word: ##rizz
# Similar: [('equati', 0.1633), ('##sicianship', 0.1616), ('ciga', 0.1611)]
# Dissimilar: ('contai', -0.181)
#
# Word: frizz
# Similar: [('vibrations', 0.8294), ('baffroom', 0.821), ('discontent', 0.8147)]
# Dissimilar: ('outdoors', -0.586)
#
# Word: spazzo
# Similar: [('##wha', 0.17), ('camb', 0.1615), ('##lfway', 0.1608)]
# Dissimilar: ('stai', -0.1895)
#
# Word: spazzol
# Similar: [('##nput', 0.2246), ('submissiv', 0.2158), ('##ant', 0.1727)]
# Dissimilar: ('spar', -0.1854)
#
# Word: spazzola
# Similar: [('yall', 0.6276), ('seventy', 0.6113), ('allow', 0.6021)]
# Dissimilar: ('yu', -0.4634)
#
# Word: dazzlin
# Similar: [('grav', 0.1966), ('##actical', 0.17), ('dav', 0.1674)]
# Dissimilar: ('##changing', -0.1673)
#
# Word: dazzling
# Similar: [('pastor', 0.7836), ('cert', 0.7711), ('racist', 0.7673)]
# Dissimilar: ('hugely', -0.3866)
#
# Word: ##az
# Similar: [('##aceful', 0.1785), ('negl', 0.1728), ('##ntal', 0.1653)]
# Dissimilar: ('bondmusing', -0.1929)
#
# Word: ##maz
# Similar: [('wimp', 0.1941), ('##sibi', 0.1775), ('russell', 0.1726)]
# Dissimilar: ('##ponsibl', -0.177)
#
# Word: daz
# Similar: [('disa', 0.2107), ('perfume', 0.188), ('wav', 0.1877)]
# Dissimilar: ('##uth', -0.1871)
#
# Word: ##azy
# Similar: [('pupp', 0.1845), ('gathe', 0.1783), ('vibrate', 0.1749)]
# Dissimilar: ('your', -0.183)
#
# Word: lazy
# Similar: [('sip', 0.8922), ('fantastic', 0.8855), ('smart', 0.8844)]
# Dissimilar: ('awards', -0.7571)
#
# Word: gaz
# Similar: [('oppos', 0.1797), ('max', 0.171), ('compute', 0.1695)]
# Dissimilar: ('fr', -0.1944)
#
# Word: maz
# Similar: [('moos', 0.1943), ('dragge', 0.1855), ('##rrying', 0.1788)]
# Dissimilar: ('bar', -0.1893)
#
# Word: haz
# Similar: [('##venu', 0.1895), ('respons', 0.1709), ('tria', 0.169)]
# Dissimilar: ('##efusal', -0.2106)
#
# Word: ##gaz
# Similar: [('popul', 0.196), ('##lucta', 0.1858), ('fome', 0.1815)]
# Dissimilar: ('cite', -0.1907)
#
# Word: amaz
# Similar: [('##ationship', 0.1839), ('smel', 0.1649), ('##icyc', 0.1642)]
# Dissimilar: ('wil', -0.1676)
#
# Word: ##razy
# Similar: [('##lief', 0.1888), ('##lit', 0.1751), ('disadvant', 0.1695)]
# Dissimilar: ('hid', -0.2091)
#
# Word: crazy
# Similar: [('recession', 0.8206), ('newspapers', 0.8037), ('soft', 0.8034)]
# Dissimilar: ('violence', -0.5789)
#
# Word: ##agaz
# Similar: [('##ymor', 0.1711), ('epi', 0.1643), ('##ollowing', 0.1636)]
# Dissimilar: ('##ination', -0.1741)
#
# Word: magaz
# Similar: [('purs', 0.1919), ('miche', 0.1833), ('occasionall', 0.1819)]
# Dissimilar: ('itself', -0.1795)
#
# Word: magazi
# Similar: [('##mg', 0.172), ('energiz', 0.1593), ('##athroom', 0.1588)]
# Dissimilar: ('pacifie', -0.1783)
#
# Word: magazin
# Similar: [('sincer', 0.1856), ('reassure', 0.1758), ('fruga', 0.1745)]
# Dissimilar: ('##estroying', -0.1854)
#
# Word: ##iz
# Similar: [('##ears', 0.1891), ('crais', 0.1828), ('whil', 0.1817)]
# Dissimilar: ('wednesday', -0.2046)
#
# Word: ab
# Similar: [('spar', 0.1836), ('haba', 0.1808), ('##llig', 0.1745)]
# Dissimilar: ('toxin', -0.1775)
#
# Word: abo
# Similar: [('##ptionally', 0.1916), ('cinnamo', 0.185), ('##xu', 0.1605)]
# Dissimilar: ('fac', -0.1955)
#
# Word: abou
# Similar: [('##eacting', 0.203), ('less', 0.1958), ('spending', 0.1755)]
# Dissimilar: ('stunne', -0.1838)
#
# Word: abov
# Similar: [('obstacle', 0.1973), ('jaso', 0.1766), ('##mbranc', 0.175)]
# Dissimilar: ('hill', -0.1866)
#
# Word: about
# Similar: [('by', 0.4885), ('progressively', 0.4578), ('acne', 0.4465)]
# Dissimilar: ('ed', -0.3091)
#
# Word: aboun
# Similar: [('##mu', 0.1814), ('seque', 0.1739), ('portla', 0.1665)]
# Dissimilar: ('##earning', -0.239)
#
# Word: abound
# Similar: [('cave', 0.9435), ('society', 0.9276), ('australia', 0.9186)]
# Dissimilar: ('internally', -0.7693)
#
# Word: ##upp
# Similar: [('promoti', 0.1938), ('basical', 0.1798), ('##wful', 0.1646)]
# Dissimilar: ('ene', -0.2035)
#
# Word: supp
# Similar: [('cheer', 0.2002), ('cognitiv', 0.1846), ('##mand', 0.1791)]
# Dissimilar: ('unfo', -0.1668)
#
# Word: pupp
# Similar: [('##azy', 0.1845), ('##tually', 0.1807), ('##atl', 0.1783)]
# Dissimilar: ('##ebellious', -0.2193)
#
# Word: puppy
# Similar: [('raging', 0.8187), ('chore', 0.8187), ('charity', 0.8131)]
# Dissimilar: ('awards', -0.6819)
#
# Word: suppo
# Similar: [('##rably', 0.1863), ('##stad', 0.1758), ('##lking', 0.169)]
# Dissimilar: ('##po', -0.1947)
#
# Word: suppor
# Similar: [('##eamworld', 0.1772), ('##ug', 0.1755), ('screenwrit', 0.1705)]
# Dissimilar: ('bung', -0.1924)
#
# Word: suppos
# Similar: [('vio', 0.1816), ('miracle', 0.1788), ('##gs', 0.1786)]
# Dissimilar: ('##atl', -0.1844)
#
# Word: support
# Similar: [('bedroom', 0.8894), ('soap', 0.8837), ('shoelace', 0.8773)]
# Dissimilar: ('dats', -0.7002)
#
# Word: ##ppy
# Similar: [('lighth', 0.193), ('bonu', 0.1771), ('##esp', 0.1761)]
# Dissimilar: ('besides', -0.1986)
#
# Word: ##appy
# Similar: [('##ensory', 0.1883), ('opinio', 0.1721), ('kindne', 0.1697)]
# Dissimilar: ('rabbi', -0.1963)
#
# Word: happy
# Similar: [('stickiness', 0.8924), ('bothersome', 0.8771), ('weep', 0.8705)]
# Dissimilar: ('awards', -0.72)
#
# Word: ##happy
# Similar: [('##day', 0.222), ('##dur', 0.2044), ('unprot', 0.1938)]
# Dissimilar: ('##rdo', -0.2325)
#
# Word: ##rappy
# Similar: [('##riday', 0.1978), ('faculti', 0.1809), ('mut', 0.1769)]
# Dissimilar: ('##ky', -0.2067)
#
# Word: crappy
# Similar: [('drained', 0.9247), ('routine', 0.9119), ('ecstatic', 0.9116)]
# Dissimilar: ('awards', -0.781)
#
# Word: opp
# Similar: [('##ogg', 0.2017), ('eulali', 0.1943), ('gow', 0.1854)]
# Dissimilar: ('naus', -0.1799)
#
# Word: ##nhappy
# Similar: [('##xis', 0.2039), ('loves', 0.1956), ('##ai', 0.183)]
# Dissimilar: ('##nuf', -0.1848)
#
# Word: unhappy
# Similar: [('vunerable', 0.8861), ('gorgeous', 0.8739), ('rules', 0.8735)]
# Dissimilar: ('awards', -0.7183)
#
# Word: oppo
# Similar: [('##sking', 0.1915), ('##mind', 0.1835), ('##lings', 0.1705)]
# Dissimilar: ('wrink', -0.2049)
#
# Word: oppr
# Similar: [('boots', 0.1682), ('tur', 0.1673), ('empathiz', 0.1649)]
# Dissimilar: ('##bal', -0.1963)
#
# Word: oppor
# Similar: [('intub', 0.1709), ('##ault', 0.1689), ('##iifff', 0.1675)]
# Dissimilar: ('smears', -0.1858)
#
# Word: oppos
# Similar: [('grandmoth', 0.1897), ('gaz', 0.1797), ('##lax', 0.1745)]
# Dissimilar: ('ph', -0.2154)
#
# Word: opport
# Similar: [('anoth', 0.1716), ('##dwich', 0.1697), ('psychologis', 0.1659)]
# Dissimilar: ('##nerations', -0.2081)
#
# Word: opportu
# Similar: [('worl', 0.195), ('##eteriorat', 0.178), ('##itiv', 0.1751)]
# Dissimilar: ('##uch', -0.216)
#
# Word: opportun
# Similar: [('##rition', 0.1766), ('determine', 0.175), ('##ationship', 0.1693)]
# Dissimilar: ('##oci', -0.202)
#
# Word: opportuni
# Similar: [('rust', 0.2069), ('psychologi', 0.2056), ('##sicianship', 0.1955)]
# Dissimilar: ('repay', -0.1605)
#
# Word: opportunit
# Similar: [('peacefuln', 0.1886), ('##liz', 0.183), ('spee', 0.177)]
# Dissimilar: ('describ', -0.1626)
#
# Word: opportunity
# Similar: [('club', 0.8131), ('corners', 0.8069), ('mourn', 0.8029)]
# Dissimilar: ('dats', -0.6098)
#
# Word: opposi
# Similar: [('##nly', 0.1865), ('##j', 0.1832), ('unprepar', 0.1698)]
# Dissimilar: ('##nclud', -0.2373)
#
# Word: opposit
# Similar: [('misinforme', 0.1883), ('anim', 0.1879), ('becom', 0.1791)]
# Dissimilar: ('##dow', -0.1843)
#
# Word: supporti
# Similar: [('confi', 0.1819), ('##ollowing', 0.1739), ('bitt', 0.1686)]
# Dissimilar: ('halluci', -0.1982)
#
# Word: supportiv
# Similar: [('##aduation', 0.1893), ('dragg', 0.1835), ('##eight', 0.172)]
# Dissimilar: ('tourist', -0.195)
#
# Word: supportin
# Similar: [('cartwhe', 0.1917), ('hospit', 0.1814), ('##cibl', 0.1766)]
# Dissimilar: ('##ippy', -0.1743)
#
# Word: supporting
# Similar: [('subject', 0.7154), ('unhappy', 0.7145), ('unusual', 0.7113)]
# Dissimilar: ('violence', -0.5813)
#
# Word: yo
# Similar: [('##stanc', 0.2283), ('##nstagram', 0.1921), ('##wor', 0.1843)]
# Dissimilar: ('##eadach', -0.1811)
#
# Word: you
# Similar: [('they', 0.8388), ('we', 0.7761), ('tenge', 0.6647)]
# Dissimilar: ('latte', -0.4273)
#
# Word: yor
# Similar: [('wi', 0.1675), ('pretzel', 0.1674), ('##ficia', 0.1629)]
# Dissimilar: ('triumpha', -0.1826)
#
# Word: york
# Similar: [('situations', 0.7898), ('indonesia', 0.7462), ('maze', 0.7196)]
# Dissimilar: ('dats', -0.4891)
#
# Word: yog
# Similar: [('##ya', 0.1999), ('##rform', 0.1879), ('clam', 0.1854)]
# Dissimilar: ('sunday', -0.1828)
#
# Word: yoga
# Similar: [('blue', 0.8958), ('extensions', 0.8824), ('baking', 0.878)]
# Dissimilar: ('dats', -0.6847)
#
# Word: squ
# Similar: [('limitati', 0.2199), ('tabl', 0.2161), ('##lation', 0.1889)]
# Dissimilar: ('##etaway', -0.1886)
#
# Word: exci
# Similar: [('diffic', 0.1812), ('indicat', 0.1722), ('packag', 0.1621)]
# Dissimilar: ('gon', -0.1822)
#
# Word: excit
# Similar: [('##hh', 0.1989), ('patriotis', 0.1904), ('disappointm', 0.1774)]
# Dissimilar: ('enquiri', -0.1752)
#
# Word: app
# Similar: [('afae', 0.1717), ('##ett', 0.165), ('impossible', 0.1631)]
# Dissimilar: ('powe', -0.1714)
#
# Word: ##app
# Similar: [('##estilence', 0.1873), ('bf', 0.1655), ('recipes', 0.1631)]
# Dissimilar: ('##itant', -0.1737)
#
# Word: happ
# Similar: [('##ina', 0.1965), ('aimle', 0.1732), ('discomf', 0.1722)]
# Dissimilar: ('##att', -0.2004)
#
# Word: ##sapp
# Similar: [('encounte', 0.1898), ('gran', 0.1755), ('chuffe', 0.1747)]
# Dissimilar: ('reinforc', -0.1934)
#
# Word: capp
# Similar: [('hedge', 0.8115), ('previous', 0.8008), ('record', 0.8006)]
# Dissimilar: ('oblige', -0.4918)
#
# Word: lapp
# Similar: [('prop', 0.1796), ('freaking', 0.1647), ('##ntub', 0.1628)]
# Dissimilar: ('shinob', -0.1747)
#
# Word: ##isapp
# Similar: [('##ctural', 0.1982), ('zealand', 0.197), ('##fuln', 0.1872)]
# Dissimilar: ('hous', -0.1756)
#
# Word: disapp
# Similar: [('betwee', 0.1891), ('##exual', 0.1751), ('denounce', 0.1747)]
# Dissimilar: ('##rning', -0.1761)
#
# Word: lappi
# Similar: [('##lings', 0.1879), ('##ubb', 0.1813), ('disillu', 0.179)]
# Dissimilar: ('##rmor', -0.1812)
#
# Word: ##rapp
# Similar: [('guit', 0.1926), ('##luidly', 0.1902), ('tigge', 0.1754)]
# Dissimilar: ('effo', -0.1902)
#
# Word: grapp
# Similar: [('embr', 0.2071), ('jens', 0.1817), ('##eas', 0.1763)]
# Dissimilar: ('amazingn', -0.2539)
#
# Word: wrapp
# Similar: [('el', 0.2286), ('##emplat', 0.173), ('califo', 0.1719)]
# Dissimilar: ('hundr', -0.1921)
#
# Word: ##appr
# Similar: [('caugh', 0.1831), ('orthot', 0.1818), ('hike', 0.1721)]
# Dissimilar: ('sending', -0.2078)
#
# Word: grappl
# Similar: [('##dag', 0.1902), ('dissolving', 0.1884), ('##sation', 0.1878)]
# Dissimilar: ('shatt', -0.1896)
#
# Word: grappli
# Similar: [('cramp', 0.173), ('subar', 0.1729), ('tune', 0.1684)]
# Dissimilar: ('##cibl', -0.194)
#
# Word: grapplin
# Similar: [('##work', 0.1998), ('##eaf', 0.1891), ('##lish', 0.1878)]
# Dissimilar: ('jil', -0.1744)
#
# Word: grappling
# Similar: [('waking', 0.8358), ('fluffed', 0.8333), ('luck', 0.8096)]
# Dissimilar: ('gently', -0.592)
#
# Word: lappin
# Similar: [('catapulte', 0.188), ('##termination', 0.1875), ('##escription', 0.1838)]
# Dissimilar: ('##mwor', -0.2086)
#
# Word: lapping
# Similar: [('news', 0.7582), ('skeleton', 0.7532), ('smell', 0.7458)]
# Dissimilar: ('oblige', -0.4996)
#
# Word: ##nappr
# Similar: [('##rious', 0.1876), ('pad', 0.1729), ('plugge', 0.1658)]
# Dissimilar: ('##irty', -0.1847)
#
# Word: unappr
# Similar: [('mosquit', 0.1947), ('capita', 0.1809), ('fome', 0.166)]
# Dissimilar: ('collecte', -0.1729)
#
# Word: appr
# Similar: [('cowor', 0.1987), ('##conomy', 0.1671), ('procedur', 0.1667)]
# Dissimilar: ('teenag', -0.1857)
#
# Word: disappo
# Similar: [('##fs', 0.2188), ('##ttl', 0.2047), ('##empting', 0.1916)]
# Dissimilar: ('##adiation', -0.1829)
#
# Word: disappoi
# Similar: [('##gativity', 0.2093), ('##arts', 0.1688), ('uncomforta', 0.1658)]
# Dissimilar: ('belittl', -0.2074)
#
# Word: disappoin
# Similar: [('##tir', 0.1938), ('langua', 0.1843), ('##scrib', 0.1833)]
# Dissimilar: ('##rich', -0.1962)
#
# Word: disappoint
# Similar: [('relax', 0.9438), ('bless', 0.9408), ('fuck', 0.9389)]
# Dissimilar: ('internally', -0.682)
#
# Word: disappointm
# Similar: [('criticiz', 0.182), ('excit', 0.1774), ('##ersonal', 0.1618)]
# Dissimilar: ('unusuall', -0.1931)
#
# Word: ##mp
# Similar: [('socie', 0.18), ('##ulous', 0.176), ('##ntimida', 0.1695)]
# Dissimilar: ('##ranqui', -0.196)
#
# Word: emp
# Similar: [('smooth', 0.2168), ('toward', 0.1906), ('cinnamo', 0.1838)]
# Dissimilar: ('thacker', -0.1797)
#
# Word: ##opp
# Similar: [('flakiness', 0.198), ('sliding', 0.1963), ('backlogs', 0.1956)]
# Dissimilar: ('##yy', -0.1963)
#
# Word: copp
# Similar: [('becoming', 0.1767), ('everytim', 0.1742), ('fortunat', 0.1724)]
# Dissimilar: ('##lviv', -0.1966)
#
# Word: ##hopp
# Similar: [('flatten', 0.219), ('activitie', 0.1938), ('traditiona', 0.1854)]
# Dissimilar: ('unwelcom', -0.1699)
#
# Word: shopp
# Similar: [('sukka', 0.1914), ('affirma', 0.174), ('##ssity', 0.1711)]
# Dissimilar: ('##avor', -0.1903)
#
# Word: popp
# Similar: [('sugg', 0.1895), ('tech', 0.1841), ('outdoor', 0.1757)]
# Dissimilar: ('##divid', -0.2012)
#
# Word: shoppi
# Similar: [('curre', 0.2021), ('snoo', 0.1756), ('##mory', 0.1669)]
# Dissimilar: ('##ign', -0.1709)
#
# Word: ##ipp
# Similar: [('##riday', 0.2154), ('shov', 0.1942), ('ei', 0.1873)]
# Dissimilar: ('cla', -0.2068)
#
# Word: ripp
# Similar: [('penye', 0.1726), ('eleme', 0.1675), ('##liev', 0.1647)]
# Dissimilar: ('##racking', -0.1989)
#
# Word: rippl
# Similar: [('stai', 0.1843), ('##tim', 0.1818), ('##jor', 0.1727)]
# Dissimilar: ('obliga', -0.1906)
#
# Word: rippli
# Similar: [('disre', 0.1924), ('dha', 0.1915), ('##vantag', 0.1891)]
# Dissimilar: ('siwons', -0.1912)
#
# Word: ##lipp
# Similar: [('##porting', 0.174), ('##ehaviors', 0.1668), ('##ancia', 0.1645)]
# Dissimilar: ('wat', -0.2585)
#
# Word: slipp
# Similar: [('maste', 0.184), ('##inish', 0.1771), ('hallucination', 0.1721)]
# Dissimilar: ('##oom', -0.1989)
#
# Word: flipp
# Similar: [('chap', 0.2022), ('uncomfortabl', 0.1963), ('intern', 0.1699)]
# Dissimilar: ('##tauk', -0.205)
#
# Word: ##ripp
# Similar: [('##oc', 0.1669), ('##print', 0.1631), ('##epending', 0.1614)]
# Dissimilar: ('choic', -0.1752)
#
# Word: ##tripp
# Similar: [('##dic', 0.1824), ('##ryyy', 0.169), ('##curity', 0.1593)]
# Dissimilar: ('##eady', -0.1901)
#
# Word: stripp
# Similar: [('##expect', 0.2136), ('disresp', 0.176), ('##search', 0.1748)]
# Dissimilar: ('bondmus', -0.1882)
#
# Word: shoppin
# Similar: [('abando', 0.1783), ('##othing', 0.1724), ('aff', 0.1679)]
# Dissimilar: ('showcas', -0.175)
#
# Word: shopping
# Similar: [('setting', 0.9099), ('pestilence', 0.9089), ('empathize', 0.905)]
# Dissimilar: ('awards', -0.7958)
#
# Word: ripplin
# Similar: [('unfait', 0.1928), ('ur', 0.1898), ('##rso', 0.1862)]
# Dissimilar: ('holiday', -0.1872)
#
# Word: rippling
# Similar: [('statistic', 0.9145), ('pestilence', 0.9092), ('pray', 0.8982)]
# Dissimilar: ('awards', -0.7581)
#
# Word: ##topp
# Similar: [('##sol', 0.2256), ('clou', 0.1995), ('##drooms', 0.1794)]
# Dissimilar: ('oils', -0.1954)
#
# Word: stopp
# Similar: [('coppe', 0.1941), ('##stioning', 0.1817), ('##lumb', 0.1753)]
# Dissimilar: ('joa', -0.1816)
#
# Word: topp
# Similar: [('agreem', 0.2148), ('frameborde', 0.1812), ('battere', 0.1754)]
# Dissimilar: ('drain', -0.1925)
#
# Word: ##ropp
# Similar: [('housekee', 0.185), ('distributio', 0.1847), ('##ece', 0.1821)]
# Dissimilar: ('##twh', -0.1795)
#
# Word: dropp
# Similar: [('##athon', 0.1908), ('quir', 0.1772), ('convolut', 0.17)]
# Dissimilar: ('##roj', -0.1891)
#
# Word: droppi
# Similar: [('##nd', 0.1637), ('##mog', 0.1629), ('##mg', 0.154)]
# Dissimilar: ('bedsid', -0.1792)
#
# Word: toppi
# Similar: [('carelessn', 0.1901), ('##llowful', 0.1858), ('##mains', 0.1779)]
# Dissimilar: ('naga', -0.1972)
#
# Word: droppin
# Similar: [('honoure', 0.1775), ('ntowa', 0.1744), ('succ', 0.1733)]
# Dissimilar: ('besides', -0.202)
#
# Word: dropping
# Similar: [('heavy', 0.8796), ('tempted', 0.8728), ('starting', 0.8722)]
# Dissimilar: ('vapor', -0.7236)
#
# Word: toppin
# Similar: [('##vastating', 0.2139), ('reward', 0.1727), ('engi', 0.1725)]
# Dissimilar: ('profil', -0.1738)
#
# Word: topping
# Similar: [('figures', 0.9384), ('baffroom', 0.931), ('bedroom', 0.9286)]
# Dissimilar: ('internally', -0.789)
#
# Word: to
# Similar: [('sending', 0.5591), ('wax', 0.5012), ('disagreement', 0.4995)]
# Dissimilar: ('irwins', -0.4298)
#
# Word: no
# Similar: [('another', 0.6324), ('america', 0.6246), ('perfumes', 0.5961)]
# Dissimilar: ('wise', -0.4371)
#
# Word: now
# Similar: [('mountains', 0.6709), ('today', 0.6609), ('still', 0.6335)]
# Dissimilar: ('fetish', -0.4994)
#
# Word: not
# Similar: [('sure', 0.6255), ('chuffed', 0.6188), ('pacing', 0.61)]
# Dissimilar: ('greg', -0.4438)
#
# Word: xm
# Similar: [('hau', 0.2122), ('##licious', 0.1897), ('ge', 0.1833)]
# Dissimilar: ('##eign', -0.1935)
#
# Word: xma
# Similar: [('bounc', 0.1697), ('puzzl', 0.1679), ('##cal', 0.1632)]
# Dissimilar: ('##oor', -0.182)
#
# Word: xmas
# Similar: [('yearn', 0.8822), ('christ', 0.87), ('wouldve', 0.867)]
# Dissimilar: ('internally', -0.7133)
#
# Word: ##jo
# Similar: [('forge', 0.1839), ('vibra', 0.1717), ('cycl', 0.164)]
# Dissimilar: ('conne', -0.1927)
#
# Word: ##joy
# Similar: [('supermark', 0.1785), ('critic', 0.1648), ('uncon', 0.1568)]
# Dissimilar: ('sid', -0.178)
#
# Word: ##jor
# Similar: [('cupca', 0.1891), ('plight', 0.1745), ('rippl', 0.1727)]
# Dissimilar: ('##dmiration', -0.1981)
#
# Word: ##ajor
# Similar: [('charre', 0.1913), ('##nov', 0.187), ('gutt', 0.1849)]
# Dissimilar: ('##plac', -0.1807)
#
# Word: major
# Similar: [('wuss', 0.7181), ('consuming', 0.6935), ('cheese', 0.6898)]
# Dissimilar: ('oblige', -0.4621)
#
# Word: ##njoy
# Similar: [('motivate', 0.1858), ('cath', 0.1748), ('##elief', 0.1721)]
# Dissimilar: ('distur', -0.2152)
#
# Word: enjoy
# Similar: [('reveal', 0.8923), ('start', 0.8868), ('reach', 0.8786)]
# Dissimilar: ('internally', -0.7382)
#
# Word: empt
# Similar: [('##obl', 0.1666), ('##ngu', 0.165), ('fathe', 0.1611)]
# Dissimilar: ('##clin', -0.1842)
#
# Word: empty
# Similar: [('ecstatic', 0.8826), ('card', 0.8596), ('clay', 0.8554)]
# Dissimilar: ('awards', -0.7452)
#
# Word: emph
# Similar: [('victimiz', 0.1999), ('atmosph', 0.1953), ('##rsus', 0.181)]
# Dissimilar: ('##ymor', -0.1924)
#
# Word: empha
# Similar: [('##ebsit', 0.1815), ('continuousl', 0.1777), ('##egativ', 0.1675)]
# Dissimilar: ('guita', -0.1867)
#
# Word: emphas
# Similar: [('##nde', 0.1711), ('##gacy', 0.1693), ('##lirty', 0.1681)]
# Dissimilar: ('##elfish', -0.1648)
#
# Word: emphasiz
# Similar: [('unn', 0.1938), ('tas', 0.1794), ('ministers', 0.1743)]
# Dissimilar: ('apolog', -0.1975)
#
# Word: emphasi
# Similar: [('burd', 0.1882), ('opini', 0.1743), ('runni', 0.1727)]
# Dissimilar: ('##art', -0.2464)
#
# Word: emphasis
# Similar: [('##rforman', 0.1785), ('##rush', 0.1774), ('##rmak', 0.1738)]
# Dissimilar: ('##stion', -0.179)
#
# Word: empti
# Similar: [('marriages', 0.232), ('lettuce', 0.2216), ('com', 0.2192)]
# Dissimilar: ('##epeating', -0.1713)
#
# Word: ##ng
# Similar: [('enact', 0.1883), ('##eapot', 0.1777), ('exhib', 0.1582)]
# Dissimilar: ('structur', -0.1866)
#
# Word: ##gh
# Similar: [('##rthday', 0.1954), ('##eyv', 0.1803), ('##utritional', 0.1746)]
# Dissimilar: ('communicati', -0.1724)
#
# Word: ##giz
# Similar: [('doubl', 0.2025), ('##eaceful', 0.1729), ('##reaking', 0.1646)]
# Dissimilar: ('convo', -0.1887)
#
# Word: ##ugh
# Similar: [('barrag', 0.1903), ('lat', 0.1746), ('figs', 0.1714)]
# Dissimilar: ('unwi', -0.181)
#
# Word: ##igh
# Similar: [('##rain', 0.1851), ('childhoo', 0.1785), ('##erms', 0.1662)]
# Dissimilar: ('cy', -0.1677)
#
# Word: nigh
# Similar: [('##termination', 0.1715), ('hostil', 0.17), ('mus', 0.1649)]
# Dissimilar: ('enabl', -0.1868)
#
# Word: righ
# Similar: [('promo', 0.19), ('##netic', 0.1839), ('distribut', 0.1838)]
# Dissimilar: ('##moriz', -0.1768)
#
# Word: migh
# Similar: [('distu', 0.1751), ('yardag', 0.1736), ('callou', 0.1689)]
# Dissimilar: ('obse', -0.2106)
#
# Word: right
# Similar: [('unsuccessful', 0.6216), ('comparing', 0.6133), ('humble', 0.6037)]
# Dissimilar: ('ed', -0.4179)
#
# Word: night
# Similar: [('time', 0.6985), ('type', 0.6941), ('copies', 0.694)]
# Dissimilar: ('awards', -0.4792)
#
# Word: might
# Similar: [('should', 0.8572), ('would', 0.8511), ('could', 0.8304)]
# Dissimilar: ('internally', -0.4756)
#
# Word: ##ough
# Similar: [('unwor', 0.1871), ('chronic', 0.1773), ('gl', 0.1753)]
# Dissimilar: ('tempte', -0.181)
#
# Word: though
# Similar: [('if', 0.7443), ('pure', 0.6906), ('why', 0.6791)]
# Dissimilar: ('youthful', -0.4916)
#
# Word: ##augh
# Similar: [('dv', 0.1921), ('blu', 0.1762), ('fang', 0.1726)]
# Dissimilar: ('tigge', -0.1753)
#
# Word: naugh
# Similar: [('honke', 0.1943), ('nef', 0.1802), ('nation', 0.175)]
# Dissimilar: ('legitimat', -0.1757)
#
# Word: ough
# Similar: [('comb', 0.1823), ('else', 0.1691), ('trolle', 0.1661)]
# Dissimilar: ('zone', -0.2071)
#
# Word: laugh
# Similar: [('christ', 0.9205), ('volunteer', 0.9179), ('vow', 0.9169)]
# Dissimilar: ('internally', -0.7976)
#
# Word: caugh
# Similar: [('theyv', 0.1942), ('##appr', 0.1831), ('##nsity', 0.1764)]
# Dissimilar: ('disillus', -0.2068)
#
# Word: daugh
# Similar: [('couldv', 0.1814), ('##vamp', 0.1715), ('##esolv', 0.1661)]
# Dissimilar: ('succ', -0.1968)
#
# Word: tough
# Similar: [('showca', 0.1863), ('suffo', 0.1802), ('odk', 0.1701)]
# Dissimilar: ('emoti', -0.1738)
#
# Word: hugh
# Similar: [('laurie', 0.8269), ('aka', 0.5217), ('seth', 0.4541)]
# Dissimilar: ('doesnt', -0.2968)
#
# Word: ##uugh
# Similar: [('tongu', 0.2425), ('shoul', 0.1917), ('piec', 0.1872)]
# Dissimilar: ('apocaly', -0.2505)
#
# Word: ##uuugh
# Similar: [('tb', 0.1693), ('##believ', 0.1683), ('squir', 0.1676)]
# Dissimilar: ('answ', -0.1817)
#
# Word: uuuugh
# Similar: [('awards', 0.5629), ('gently', 0.5358), ('answers', 0.5241)]
# Dissimilar: ('moronic', -0.6521)
#
# Word: ##raugh
# Similar: [('frustra', 0.1931), ('ston', 0.1721), ('argue', 0.1696)]
# Dissimilar: ('##comm', -0.2002)
#
# Word: tought
# Similar: [('typed', 0.8244), ('pure', 0.8133), ('perfection', 0.8065)]
# Dissimilar: ('internally', -0.5546)
#
# Word: daught
# Similar: [('maint', 0.1789), ('trial', 0.172), ('##niqu', 0.1718)]
# Dissimilar: ('terrifie', -0.2044)
#
# Word: caught
# Similar: [('clock', 0.8893), ('empathize', 0.8696), ('refresh', 0.8621)]
# Dissimilar: ('internally', -0.6535)
#
# Word: naught
# Similar: [('##erhaps', 0.1864), ('gratefulne', 0.1689), ('gende', 0.1614)]
# Dissimilar: ('traditiona', -0.1747)
#
# Word: naughty
# Similar: [('virtuous', 0.787), ('homesick', 0.777), ('weird', 0.7768)]
# Dissimilar: ('awards', -0.6269)
#
# Word: ought
# Similar: [('sane', 0.7409), ('empathy', 0.7135), ('energetic', 0.6791)]
# Dissimilar: ('gently', -0.4986)
#
# Word: ##traugh
# Similar: [('##ntimidat', 0.1996), ('su', 0.1901), ('goog', 0.1805)]
# Dissimilar: ('##eurotic', -0.1919)
#
# Word: ##straugh
# Similar: [('impu', 0.2041), ('##rever', 0.185), ('chaba', 0.1815)]
# Dissimilar: ('##raying', -0.1844)
#
# Word: ##istraugh
# Similar: [('##mug', 0.197), ('##kwa', 0.1825), ('abi', 0.1786)]
# Dissimilar: ('convi', -0.1786)
#
# Word: distraugh
# Similar: [('##andp', 0.2458), ('sitting', 0.1816), ('baffl', 0.18)]
# Dissimilar: ('##trusion', -0.2031)
#
# Word: distraught
# Similar: [('stickiness', 0.8148), ('glad', 0.8122), ('yk', 0.8022)]
# Dissimilar: ('gently', -0.6006)
#
# Word: ##ing
# Similar: [('castle', 0.7979), ('afraid', 0.774), ('yarn', 0.7733)]
# Dissimilar: ('awards', -0.6199)
#
# Word: copping
# Similar: [('sip', 0.9348), ('relieved', 0.9231), ('smart', 0.9081)]
# Dissimilar: ('awards', -0.7376)
#
# Word: wrapping
# Similar: [('melody', 0.8203), ('rubies', 0.8061), ('denying', 0.8061)]
# Dissimilar: ('awards', -0.6168)
#
# Word: amazing
# Similar: [('offended', 0.847), ('defective', 0.845), ('outraged', 0.8343)]
# Dissimilar: ('awards', -0.6775)
#
# Word: young
# Similar: [('##llness', 0.7738), ('scad', 0.7548), ('existance', 0.7511)]
# Dissimilar: ('awards', -0.6069)
#
# Word: ##gg
# Similar: [('##lalom', 0.1965), ('consu', 0.1756), ('facilit', 0.17)]
# Dissimilar: ('root', -0.2072)
#
# Word: ##ight
# Similar: [('clam', 0.1993), ('freaking', 0.1832), ('divin', 0.1764)]
# Dissimilar: ('##magining', -0.2195)
#
# Word: high
# Similar: [('college', 0.6527), ('tummy', 0.6285), ('comparison', 0.6276)]
# Dissimilar: ('vapor', -0.4871)
#
# Word: ##ighb
# Similar: [('limitatio', 0.1733), ('##mouring', 0.1715), ('lonelin', 0.1695)]
# Dissimilar: ('cliche', -0.1743)
#
# Word: thigh
# Similar: [('stage', 0.725), ('distant', 0.7238), ('kneels', 0.715)]
# Dissimilar: ('hugely', -0.4332)
#
# Word: sigh
# Similar: [('thinner', 0.7934), ('typed', 0.7897), ('earlier', 0.7814)]
# Dissimilar: ('awards', -0.6052)
#
# Word: ##ighbo
# Similar: [('od', 0.2207), ('occa', 0.1773), ('##public', 0.1745)]
# Dissimilar: ('pian', -0.1942)
#
# Word: ##ighbor
# Similar: [('##ithf', 0.2014), ('##rrying', 0.185), ('exhibiti', 0.181)]
# Dissimilar: ('terrifie', -0.1793)
#
# Word: ##ighbors
# Similar: [('boyf', 0.1885), ('##ewspap', 0.1848), ('litte', 0.1733)]
# Dissimilar: ('unimp', -0.1816)
#
# Word: thighs
# Similar: [('pounding', 0.8724), ('weather', 0.8658), ('finger', 0.8532)]
# Dissimilar: ('dats', -0.5892)
#
# Word: ##gging
# Similar: [('grandiose', 0.1875), ('##lating', 0.17), ('ravage', 0.1657)]
# Dissimilar: ('vomi', -0.2019)
#
# Word: ##ogging
# Similar: [('decease', 0.2125), ('artisa', 0.2069), ('##erspectiv', 0.1813)]
# Dissimilar: ('stayvi', -0.194)
#
# Word: ##ugging
# Similar: [('trimming', 0.1927), ('negle', 0.1852), ('##cup', 0.1721)]
# Dissimilar: ('##shap', -0.1786)
#
# Word: ##logging
# Similar: [('##sibi', 0.1947), ('slight', 0.1853), ('passiona', 0.1784)]
# Dissimilar: ('##azz', -0.2003)
#
# Word: blogging
# Similar: [('walk', 0.7771), ('society', 0.7764), ('arcade', 0.7706)]
# Dissimilar: ('vapor', -0.5779)
#
# Word: ##lugging
# Similar: [('ambie', 0.1892), ('profi', 0.1697), ('unwelcom', 0.1697)]
# Dissimilar: ('husba', -0.2032)
#
# Word: slugging
# Similar: [('generations', 0.9339), ('vow', 0.9242), ('obstacles', 0.9196)]
# Dissimilar: ('internally', -0.8278)
#
# Word: ##agging
# Similar: [('deserte', 0.2059), ('##gum', 0.1963), ('##lody', 0.1706)]
# Dissimilar: ('##iour', -0.2087)
#
# Word: ##ragging
# Similar: [('austra', 0.1944), ('promi', 0.1836), ('obligati', 0.1805)]
# Dissimilar: ('unappreciate', -0.2126)
#
# Word: dragging
# Similar: [('inexperience', 0.8317), ('list', 0.8116), ('husband', 0.8026)]
# Dissimilar: ('internally', -0.5355)
#
# Word: ##ggy
# Similar: [('##lln', 0.1943), ('unconsc', 0.1846), ('##aska', 0.1834)]
# Dissimilar: ('absol', -0.2121)
#
# Word: ##oggy
# Similar: [('easie', 0.1765), ('##aln', 0.1744), ('##rifi', 0.1628)]
# Dissimilar: ('##egions', -0.1865)
#
# Word: ##ugg
# Similar: [('leo', 0.1877), ('ryan', 0.1829), ('##ccomplishing', 0.1762)]
# Dissimilar: ('beside', -0.1695)
#
# Word: ##roggy
# Similar: [('##stamps', 0.1901), ('cheesecak', 0.1878), ('##tori', 0.1736)]
# Dissimilar: ('thrille', -0.1684)
#
# Word: groggy
# Similar: [('vulnerable', 0.901), ('agitated', 0.8935), ('tender', 0.8907)]
# Dissimilar: ('awards', -0.7285)
#
# Word: foggy
# Similar: [('independence', 0.6212), ('repeating', 0.517), ('circumstance', 0.5098)]
# Dissimilar: ('perfectly', -0.383)
#
# Word: sugg
# Similar: [('popp', 0.1895), ('techniques', 0.1864), ('##leece', 0.1751)]
# Dissimilar: ('legitimate', -0.1824)
#
# Word: ##rugg
# Similar: [('wrappe', 0.1944), ('##cifica', 0.1847), ('##back', 0.1824)]
# Dissimilar: ('##nterests', -0.1911)
#
# Word: ##ruggl
# Similar: [('wimp', 0.1787), ('##aving', 0.1775), ('##som', 0.1634)]
# Dissimilar: ('burg', -0.1825)
#
# Word: ##ruggling
# Similar: [('##yenas', 0.2285), ('##tupid', 0.1802), ('whol', 0.179)]
# Dissimilar: ('crush', -0.1928)
#
# Word: ##lugg
# Similar: [('##ndblog', 0.1734), ('##ourous', 0.1564), ('##eumonia', 0.1561)]
# Dissimilar: ('##irtuous', -0.206)
#
# Word: plugg
# Similar: [('afra', 0.1881), ('lis', 0.1801), ('films', 0.1753)]
# Dissimilar: ('getting', -0.2091)
#
# Word: ##truggling
# Similar: [('slop', 0.184), ('burg', 0.1835), ('haun', 0.174)]
# Dissimilar: ('##tia', -0.1775)
#
# Word: struggling
# Similar: [('save', 0.875), ('integrity', 0.8722), ('grandfather', 0.8633)]
# Dissimilar: ('dats', -0.6111)
#
# Word: ##truggl
# Similar: [('spi', 0.2102), ('##motion', 0.1697), ('##onounc', 0.1677)]
# Dissimilar: ('##ensory', -0.1795)
#
# Word: struggl
# Similar: [('sweetn', 0.1963), ('snoot', 0.1728), ('ofte', 0.1666)]
# Dissimilar: ('##rapp', -0.1677)
#
# Word: ##igg
# Similar: [('##omy', 0.186), ('##raduation', 0.1718), ('##mo', 0.1679)]
# Dissimilar: ('requ', -0.1783)
#
# Word: nigg
# Similar: [('##itat', 0.2204), ('traditionali', 0.1868), ('##engals', 0.1716)]
# Dissimilar: ('bitterswee', -0.2031)
#
# Word: bigg
# Similar: [('consignme', 0.2155), ('##roying', 0.2097), ('joe', 0.1892)]
# Dissimilar: ('##ssari', -0.2041)
#
# Word: tigg
# Similar: [('##ator', 0.1865), ('beatles', 0.1779), ('##deral', 0.1759)]
# Dissimilar: ('cya', -0.2312)
#
# Word: ##rigg
# Similar: [('##ingapor', 0.2377), ('cite', 0.1789), ('avoi', 0.1686)]
# Dissimilar: ('orgasm', -0.2029)
#
# Word: trigg
# Similar: [('##hind', 0.1955), ('##nstruction', 0.1797), ('##rsonalit', 0.1746)]
# Dissimilar: ('##aring', -0.1754)
#
# Word: niggl
# Similar: [('pressured', 0.2364), ('assured', 0.217), ('century', 0.2066)]
# Dissimilar: ('task', -0.2144)
#
# Word: niggling
# Similar: [('mica', 0.9448), ('bittersweet', 0.9094), ('remain', 0.9076)]
# Dissimilar: ('awards', -0.7837)
#
# Word: enjoying
# Similar: [('cracks', 0.8304), ('pub', 0.8258), ('statistic', 0.8198)]
# Dissimilar: ('awards', -0.6493)
#
# Word: stopping
# Similar: [('expression', 0.7694), ('crone', 0.7456), ('hedge', 0.7383)]
# Dissimilar: ('wonders', -0.4042)
#
# Word: ung
# Similar: [('##lloons', 0.1684), ('imposs', 0.1658), ('##rblonk', 0.1651)]
# Dissimilar: ('insince', -0.1875)
#
# Word: ungr
# Similar: [('unhealthy', 0.1921), ('platonic', 0.1813), ('##ndom', 0.1783)]
# Dissimilar: ('##q', -0.1853)
#
# Word: ungra
# Similar: [('##mbering', 0.1808), ('activ', 0.1779), ('abuse', 0.1752)]
# Dissimilar: ('smothe', -0.179)
#
# Word: ungrat
# Similar: [('##gard', 0.1985), ('accomplishe', 0.1739), ('##egl', 0.1703)]
# Dissimilar: ('gratefuln', -0.196)
#
# Word: ##rgiz
# Similar: [('optimi', 0.1766), ('##vily', 0.1675), ('##lob', 0.166)]
# Dissimilar: ('##nail', -0.2141)
#
# Word: ##ogiz
# Similar: [('impractica', 0.197), ('##errific', 0.1691), ('hurr', 0.167)]
# Dissimilar: ('##fish', -0.198)
#
# Word: ##logiz
# Similar: [('##cit', 0.1756), ('crosswor', 0.169), ('##rvous', 0.1662)]
# Dissimilar: ('##atsuma', -0.175)
#
# Word: ##ologiz
# Similar: [('##ms', 0.1795), ('##ciz', 0.1754), ('costu', 0.1682)]
# Dissimilar: ('##ox', -0.2079)
#
# Word: ##pologiz
# Similar: [('mys', 0.173), ('##turn', 0.1669), ('curi', 0.1658)]
# Dissimilar: ('hurr', -0.1814)
#
# Word: apologiz
# Similar: [('##mmog', 0.1976), ('##mini', 0.1892), ('aff', 0.1794)]
# Dissimilar: ('##giti', -0.1703)
#
# Word: ##ch
# Similar: [('repr', 0.1722), ('##rwin', 0.1705), ('suk', 0.1673)]
# Dissimilar: ('##produc', -0.2061)
#
# Word: ##uch
# Similar: [('##empl', 0.1777), ('memori', 0.1738), ('##ryyyy', 0.164)]
# Dissimilar: ('opportu', -0.216)
#
# Word: much
# Similar: [('evident', 0.7256), ('regimented', 0.7012), ('cheap', 0.6708)]
# Dissimilar: ('vapor', -0.486)
#
# Word: such
# Similar: [('police', 0.7931), ('critical', 0.7828), ('comatose', 0.7766)]
# Dissimilar: ('violence', -0.5498)
#
# Word: touch
# Similar: [('setting', 0.8423), ('soul', 0.841), ('sciences', 0.839)]
# Dissimilar: ('gently', -0.676)
#
# Word: ##uchy
# Similar: [('attachme', 0.1955), ('##eact', 0.1749), ('communicate', 0.1727)]
# Dissimilar: ('##row', -0.1952)
#
# Word: ##ouchy
# Similar: [('##ously', 0.1922), ('incidents', 0.1883), ('colu', 0.185)]
# Dissimilar: ('compe', -0.2104)
#
# Word: ##rouchy
# Similar: [('odk', 0.2052), ('suffo', 0.1925), ('##entful', 0.1822)]
# Dissimilar: ('ifram', -0.1765)
#
# Word: grouchy
# Similar: [('disorganised', 0.9229), ('alaska', 0.9206), ('routine', 0.9197)]
# Dissimilar: ('awards', -0.7545)
#
# Word: exh
# Similar: [('##cently', 0.1833), ('##sponsibl', 0.1787), ('##vestat', 0.1764)]
# Dissimilar: ('furthe', -0.2149)
#
# Word: exha
# Similar: [('vers', 0.2101), ('##ndom', 0.1696), ('##aki', 0.1669)]
# Dissimilar: ('suitcas', -0.229)
#
# Word: exhau
# Similar: [('chok', 0.1863), ('##ator', 0.1809), ('##erdy', 0.1546)]
# Dissimilar: ('##egards', -0.2011)
#
# Word: exhi
# Similar: [('##easing', 0.1906), ('supermarke', 0.1808), ('energe', 0.1754)]
# Dissimilar: ('psychopatholo', -0.1791)
#
# Word: exhib
# Similar: [('##isma', 0.1853), ('##reacting', 0.1745), ('##ustration', 0.1705)]
# Dissimilar: ('toxi', -0.1717)
#
# Word: exhibi
# Similar: [('##emo', 0.169), ('coloure', 0.1658), ('prefe', 0.1621)]
# Dissimilar: ('##stood', -0.1872)
#
# Word: exhaus
# Similar: [('purcha', 0.1755), ('##esistant', 0.1725), ('exhilarat', 0.1716)]
# Dissimilar: ('minor', -0.1988)
#
# Word: exhil
# Similar: [('seam', 0.1827), ('inge', 0.1811), ('emoticons', 0.1642)]
# Dissimilar: ('chuff', -0.1988)
#
# Word: exhal
# Similar: [('chab', 0.1981), ('##ndiff', 0.1816), ('##peatedly', 0.1787)]
# Dissimilar: ('##rpetually', -0.1824)
#
# Word: exhaling
# Similar: [('annoying', 0.8424), ('preparing', 0.8219), ('stunned', 0.8112)]
# Dissimilar: ('awards', -0.6366)
#
# Word: exhila
# Similar: [('easil', 0.1971), ('spon', 0.1874), ('archi', 0.1834)]
# Dissimilar: ('##ighbors', -0.1729)
#
# Word: exhilar
# Similar: [('vitamins', 0.1866), ('cantank', 0.181), ('##sman', 0.1799)]
# Dissimilar: ('teng', -0.1708)
#
# Word: exhilara
# Similar: [('piss', 0.2093), ('##lubb', 0.1926), ('purs', 0.191)]
# Dissimilar: ('##mbulanc', -0.1886)
#
# Word: exhaust
# Similar: [('##dori', 0.2274), ('##oi', 0.2154), ('##encumb', 0.1971)]
# Dissimilar: ('##ook', -0.18)
#
# Word: exhibit
# Similar: [('devote', 0.6841), ('apron', 0.6828), ('hit', 0.671)]
# Dissimilar: ('initiation', -0.6913)
#
# Word: exhilarat
# Similar: [('##antic', 0.2261), ('au', 0.1975), ('promi', 0.176)]
# Dissimilar: ('##ink', -0.1702)
#
# ...
# Dissimilar: ('gently', -0.579)
#
# Word: ##eeally
# Similar: [('##ndwich', 0.1782), ('##reby', 0.1766), ('##diocy', 0.1737)]
# Dissimilar: ('##ssings', -0.1958)
#
# Word: ##eeeally
# Similar: [('rath', 0.19), ('zamb', 0.1826), ('##ato', 0.1805)]
# Dissimilar: ('##endid', -0.1732)
#
# Word: ##eeeeally
# Similar: [('##emingly', 0.1743), ('devic', 0.1643), ('esca', 0.1632)]
# Dissimilar: ('hoho', -0.1972)
#
# Word: ##eeeeeally
# Similar: [('##ain', 0.2003), ('shap', 0.1851), ('amaze', 0.1766)]
# Dissimilar: ('gam', -0.1982)
#
# Word: ##eeeeeeally
# Similar: [('rte', 0.1704), ('sham', 0.1668), ('##ativit', 0.1607)]
# Dissimilar: ('##sonat', -0.2152)
#
# Word: ##eeeeeeeally
# Similar: [('priva', 0.1885), ('##earin', 0.1792), ('facilit', 0.1753)]
# Dissimilar: ('##finit', -0.1943)
#
# Word: ##eeeeeeeeally
# Similar: [('wov', 0.2289), ('ting', 0.2095), ('affirmat', 0.1974)]
# Dissimilar: ('disori', -0.1866)
#
# Word: reeeeeeeeally
# Similar: [('incomes', 0.7136), ('morbid', 0.6597), ('stops', 0.629)]
# Dissimilar: ('gently', -0.4864)
#
# Word: ##em
# Similar: [('##ersonality', 0.2313), ('triumph', 0.1859), ('unknow', 0.1851)]
# Dissimilar: ('##forwarding', -0.2157)
#
# Word: rem
# Similar: [('patri', 0.1874), ('aligncenter', 0.1807), ('passing', 0.173)]
# Dissimilar: ('shad', -0.1819)
#
# Word: stem
# Similar: [('rippling', 0.86), ('barrier', 0.8562), ('trimmings', 0.8551)]
# Dissimilar: ('awards', -0.6753)
#
# Word: ism
# Similar: [('conclusions', 0.7213), ('hurry', 0.72), ('hive', 0.7139)]
# Dissimilar: ('vapor', -0.4602)
#
# Word: reme
# Similar: [('##obing', 0.1983), ('jame', 0.198), ('##cul', 0.182)]
# Dissimilar: ('##uition', -0.1802)
#
# Word: rememb
# Similar: [('someon', 0.1864), ('eith', 0.1736), ('##ntly', 0.1718)]
# Dissimilar: ('##cad', -0.1923)
#
# Word: rmb
# Similar: [('flung', 0.9269), ('print', 0.9063), ('exspress', 0.8902)]
# Dissimilar: ('internally', -0.7339)
#
# Word: remembe
# Similar: [('##kful', 0.1814), ('rush', 0.1792), ('##mbering', 0.1776)]
# Dissimilar: ('sentin', -0.1581)
#
# Word: remember
# Similar: [('am', 0.8545), ('stopped', 0.8435), ('related', 0.8081)]
# Dissimilar: ('awards', -0.5216)
#
# Word: ##rt
# Similar: [('intellect', 0.2029), ('buys', 0.1797), ('building', 0.1788)]
# Dissimilar: ('compassionat', -0.2009)
#
# Word: ##eem
# Similar: [('occasio', 0.1925), ('##iculous', 0.1722), ('##liz', 0.1701)]
# Dissimilar: ('doome', -0.1766)
#
# Word: seem
# Similar: [('ask', 0.9365), ('fail', 0.9135), ('expect', 0.9069)]
# Dissimilar: ('internally', -0.7973)
#
# Word: ##deem
# Similar: [('potentially', 0.2085), ('trim', 0.1764), ('##lon', 0.1741)]
# Dissimilar: ('##mmogr', -0.2379)
#
# Word: ##emb
# Similar: [('##rifi', 0.2001), ('##lyh', 0.183), ('quir', 0.1689)]
# Dissimilar: ('rank', -0.1767)
#
# Word: memb
# Similar: [('logi', 0.1711), ('effe', 0.1705), ('##ariju', 0.1674)]
# Dissimilar: ('prohibition', -0.1927)
#
# Word: membe
# Similar: [('hanfo', 0.2155), ('##ump', 0.1769), ('apocaly', 0.1756)]
# Dissimilar: ('nak', -0.2109)
#
# Word: members
# Similar: [('desserts', 0.7345), ('auster', 0.6881), ('trigger', 0.688)]
# Dissimilar: ('dats', -0.5254)
#
# Word: member
# Similar: [('mensa', 0.676), ('lovebox', 0.6227), ('least', 0.5994)]
# Dissimilar: ('to', -0.3185)
#
# Word: ##ert
# Similar: [('##aying', 0.2111), ('mov', 0.1953), ('artist', 0.1795)]
# Dissimilar: ('sadden', -0.1636)
#
# Word: cert
# Similar: [('dazzling', 0.7711), ('accident', 0.7689), ('tug', 0.758)]
# Dissimilar: ('entail', -0.4361)
#
# Word: ##ssert
# Similar: [('##damn', 0.1734), ('peacefuln', 0.1708), ('##racting', 0.168)]
# Dissimilar: ('##ault', -0.177)
#
# Word: ##sert
# Similar: [('famil', 0.1748), ('happ', 0.1707), ('dubl', 0.165)]
# Dissimilar: ('humanit', -0.1837)
#
# Word: ##essert
# Similar: [('##s', 0.2001), ('provided', 0.1993), ('yu', 0.1987)]
# Dissimilar: ('graduat', -0.2053)
#
# Word: dessert
# Similar: [('lamb', 0.7633), ('idiot', 0.7622), ('oregon', 0.7595)]
# Dissimilar: ('headaches', -0.4598)
#
# Word: ##edeem
# Similar: [('affirmat', 0.1836), ('##elong', 0.1734), ('##lorid', 0.1721)]
# Dissimilar: ('sho', -0.1779)
#
# Word: redeem
# Similar: [('accustomed', 0.9274), ('convince', 0.9067), ('succumb', 0.8993)]
# Dissimilar: ('internally', -0.7511)
#
# Word: ##esert
# Similar: [('pos', 0.1844), ('philos', 0.1805), ('promoti', 0.1751)]
# Dissimilar: ('##oisturiz', -0.1819)
#
# Word: desert
# Similar: [('##chop', 0.1861), ('##nch', 0.1739), ('apartm', 0.1713)]
# Dissimilar: ('consta', -0.1953)
#
# Word: deserte
# Similar: [('##ination', 0.207), ('##agging', 0.2059), ('##fli', 0.1905)]
# Dissimilar: ('##up', -0.1688)
#
# Word: deserted
# Similar: [('agitated', 0.7808), ('groggy', 0.7783), ('jaded', 0.764)]
# Dissimilar: ('awards', -0.5512)
#
# Word: ##ers
# Similar: [('betraye', 0.188), ('templ', 0.1621), ('suffoc', 0.1567)]
# Dissimilar: ('abando', -0.1955)
#
# Word: customers
# Similar: [('unemployment', 0.6432), ('devestated', 0.6369), ('smart', 0.6304)]
# Dissimilar: ('internally', -0.5377)
#
# Word: flowers
# Similar: [('lyrics', 0.8714), ('issue', 0.8659), ('harbor', 0.8645)]
# Dissimilar: ('awards', -0.6764)
#
# Word: teachers
# Similar: [('appease', 0.6733), ('describe', 0.6707), ('visitor', 0.6657)]
# Dissimilar: ('cynical', -0.4183)
#
# Word: matters
# Similar: [('perceive', 0.8072), ('marry', 0.7917), ('matter', 0.7815)]
# Dissimilar: ('awards', -0.6286)
#
# Word: ##aders
# Similar: [('##luid', 0.1894), ('to', 0.1825), ('christm', 0.1732)]
# Dissimilar: ('irwins', -0.2064)
#
# Word: riders
# Similar: [('kamen', 0.7726), ('of', 0.4276), ('greg', 0.3667)]
# Dissimilar: ('really', -0.342)
#
# Word: developers
# Similar: [('hyper', 0.9119), ('devastated', 0.8986), ('defective', 0.8822)]
# Dissimilar: ('gently', -0.6836)
#
# Word: papers
# Similar: [('hurtful', 0.7981), ('tightly', 0.7944), ('unusually', 0.7654)]
# Dissimilar: ('gently', -0.6029)
#
# Word: wearers
# Similar: [('wearily', 0.9399), ('panic', 0.938), ('anthology', 0.9294)]
# Dissimilar: ('internally', -0.8219)
#
# Word: followers
# Similar: [('sweetness', 0.571), ('obrian', 0.5687), ('companion', 0.544)]
# Dissimilar: ('ghosting', -0.3296)
#
# Word: eaters
# Similar: [('circle', 0.7691), ('a', 0.4643), ('cases', 0.3889)]
# Dissimilar: ('irritate', -0.2522)
#
# Word: reminders
# Similar: [('encounter', 0.8892), ('stepped', 0.8696), ('confess', 0.8635)]
# Dissimilar: ('internally', -0.7131)
#
# Word: numbers
# Similar: [('wafts', 0.864), ('cooperation', 0.8526), ('machiavellian', 0.8483)]
# Dissimilar: ('awards', -0.6322)
#
# Word: watchers
# Similar: [('maks', 0.8137), ('bedrooms', 0.8062), ('rhythm', 0.8014)]
# Dissimilar: ('awards', -0.4958)
#
# Word: supporters
# Similar: [('paper', 0.8615), ('legions', 0.8553), ('automation', 0.8419)]
# Dissimilar: ('outdoors', -0.5603)
#
# Word: shoulders
# Similar: [('ankle', 0.9284), ('anthology', 0.9047), ('bedroom', 0.894)]
# Dissimilar: ('internally', -0.7575)
#
# Word: workers
# Similar: [('co', 0.8001), ('limitations', 0.66), ('piano', 0.6295)]
# Dissimilar: ('internally', -0.393)
#
# Word: nighters
# Similar: [('velvet', 0.7949), ('anxieties', 0.7698), ('whiney', 0.7683)]
# Dissimilar: ('awards', -0.649)
#
# Word: offers
# Similar: [('spirits', 0.6101), ('finals', 0.6079), ('appetite', 0.6072)]
# Dissimilar: ('sufficiently', -0.2992)
#
# Word: downers
# Similar: [('lacking', 0.8405), ('capable', 0.829), ('aware', 0.8204)]
# Dissimilar: ('awards', -0.671)
#
# Word: users
# Similar: [('trips', 0.6997), ('every', 0.6621), ('spending', 0.6576)]
# Dissimilar: ('shouldnt', -0.4979)
#
# Word: mrs
# Similar: [('theyve', 0.5754), ('fa', 0.5195), ('tools', 0.5026)]
# Dissimilar: ('others', -0.4109)
#
# Word: ##ners
# Similar: [('hallucinat', 0.1794), ('##rkou', 0.1787), ('##iliarity', 0.1686)]
# Dissimilar: ('encourag', -0.1902)
#
# Word: ##eaders
# Similar: [('antics', 0.1814), ('##aby', 0.1721), ('mineral', 0.1713)]
# Dissimilar: ('##irport', -0.2097)
#
# Word: readers
# Similar: [('loyal', 0.8686), ('rest', 0.8402), ('intrusion', 0.8119)]
# Dissimilar: ('dats', -0.6297)
#
# Word: ##eers
# Similar: [('croiss', 0.2128), ('##tuous', 0.179), ('##elating', 0.1708)]
# Dissimilar: ('##riz', -0.1753)
#
# Word: peers
# Similar: [('typical', 0.6412), ('he', 0.4486), ('instinctively', 0.4472)]
# Dissimilar: ('[PAD]', -0.3445)
#
# Word: careers
# Similar: [('manageable', 0.6756), ('flow', 0.6647), ('antique', 0.6566)]
# Dissimilar: ('joel', -0.4718)
#
# Word: ##eners
# Similar: [('disregard', 0.1668), ('shoppi', 0.1564), ('##mony', 0.1561)]
# Dissimilar: ('##ychologica', -0.2016)
#
# Word: sweeteners
# Similar: [('erm', 0.5793), ('browsers', 0.5699), ('incheswhyinches', 0.5637)]
# Dissimilar: ('awards', -0.4097)
#
# Word: quite
# Similar: [('festive', 0.8076), ('officially', 0.8064), ('bitter', 0.7859)]
# Dissimilar: ('awards', -0.5192)
#
# Word: ##end
# Similar: [('##yph', 0.172), ('private', 0.1677), ('promi', 0.1671)]
# Dissimilar: ('##ecip', -0.1891)
#
# Word: weekend
# Similar: [('devote', 0.8083), ('marathon', 0.7879), ('gloating', 0.7801)]
# Dissimilar: ('awards', -0.4911)
#
# Word: legend
# Similar: [('fever', 0.8879), ('cheesecake', 0.8838), ('exercised', 0.8814)]
# Dissimilar: ('awards', -0.7164)
#
# Word: offend
# Similar: [('##arriag', 0.2143), ('oblig', 0.2075), ('occasi', 0.1865)]
# Dissimilar: ('mobi', -0.2)
#
# Word: tend
# Similar: [('percieve', 0.94), ('vow', 0.9277), ('resorted', 0.9241)]
# Dissimilar: ('internally', -0.77)
#
# Word: send
# Similar: [('assistant', 0.7159), ('george', 0.6897), ('inherent', 0.6888)]
# Dissimilar: ('exhibit', -0.4533)
#
# Word: ##nde
# Similar: [('hall', 0.2197), ('uhu', 0.1903), ('##mb', 0.1811)]
# Dissimilar: ('jasmin', -0.1888)
#
# Word: ##ndee
# Similar: [('manner', 0.2467), ('feature', 0.2443), ('theres', 0.2349)]
# Dissimilar: ('limite', -0.1798)
#
# Word: ##ndeed
# Similar: [('##ex', 0.1882), ('flatte', 0.1816), ('artic', 0.1816)]
# Dissimilar: ('apocalypses', -0.195)
#
# Word: offende
# Similar: [('##vity', 0.1865), ('##ntury', 0.1706), ('wis', 0.162)]
# Dissimilar: ('cze', -0.1814)
#
# Word: offended
# Similar: [('discouraged', 0.9308), ('devastated', 0.9191), ('drained', 0.9172)]
# Dissimilar: ('awards', -0.7991)
#
# Word: come
# Similar: [('holyhead', 0.7844), ('concentrate', 0.7812), ('rise', 0.7789)]
# Dissimilar: ('vapor', -0.5895)
#
# Word: comes
# Similar: [('flee', 0.8681), ('lunchroom', 0.8498), ('wire', 0.8491)]
# Dissimilar: ('awards', -0.6862)
#
# Word: ##ead
# Similar: [('##ntelligence', 0.1973), ('bas', 0.1646), ('##dividua', 0.1645)]
# Dissimilar: ('##ventur', -0.182)
#
# Word: read
# Similar: [('emily', 0.8639), ('clench', 0.8556), ('sand', 0.8508)]
# Dissimilar: ('internally', -0.6808)
#
# Word: dread
# Similar: [('several', 0.6558), ('diy', 0.6507), ('norma', 0.6505)]
# Dissimilar: ('mike', -0.5171)
#
# Word: ##read
# Similar: [('##roud', 0.2008), ('negative', 0.1804), ('##ebellious', 0.178)]
# Dissimilar: ('rhy', -0.2132)
#
# Word: tad
# Similar: [('failure', 0.8829), ('slicing', 0.8765), ('bonus', 0.868)]
# Dissimilar: ('awards', -0.7331)
#
# Word: rt
# Similar: [('clubbed', 0.2083), ('brand', 0.1958), ('artist', 0.1739)]
# Dissimilar: ('hatte', -0.1869)
#
# Word: ##eread
# Similar: [('##anish', 0.1834), ('twit', 0.1777), ('trimeste', 0.1653)]
# Dissimilar: ('##eaning', -0.1919)
#
# Word: reread
# Similar: [('cringe', 0.937), ('brag', 0.9362), ('perceive', 0.9241)]
# Dissimilar: ('awards', -0.8064)
#
# Word: rte
# Similar: [('src', 0.6241), ('emoticons', 0.5572), ('img', 0.4552)]
# Dissimilar: ('upon', -0.1943)
#
# Word: shocke
# Similar: [('##sitor', 0.1803), ('garde', 0.1724), ('##timiz', 0.1709)]
# Dissimilar: ('##ca', -0.2099)
#
# Word: shocked
# Similar: [('surprised', 0.8958), ('drained', 0.8912), ('offended', 0.8909)]
# Dissimilar: ('awards', -0.7722)
#
# Word: hope
# Similar: [('thought', 0.9362), ('wish', 0.8932), ('suppose', 0.8866)]
# Dissimilar: ('internally', -0.7012)
#
# Word: hopel
# Similar: [('bou', 0.1954), ('marre', 0.1763), ('##finit', 0.1727)]
# Dissimilar: ('##rtuous', -0.1921)
#
# Word: hopes
# Similar: [('privileged', 0.8978), ('waits', 0.8941), ('pause', 0.8913)]
# Dissimilar: ('vapor', -0.7343)
#
# Word: hopele
# Similar: [('answers', 0.2), ('##ersonaliz', 0.1818), ('industry', 0.1801)]
# Dissimilar: ('##sonat', -0.1868)
#
# Word: hopeless
# Similar: [('uber', 0.9394), ('suffocated', 0.9258), ('blush', 0.9253)]
# Dissimilar: ('awards', -0.7793)
#
# Word: she
# Similar: [('he', 0.7883), ('i', 0.715), ('mobility', 0.6917)]
# Dissimilar: ('joel', -0.5043)
#
# Word: shr
# Similar: [('aby', 0.1783), ('##elessly', 0.1757), ('##ecord', 0.1675)]
# Dissimilar: ('zomb', -0.1771)
#
# Word: shes
# Similar: [('outcast', 0.8591), ('exclusively', 0.816), ('hurt', 0.8053)]
# Dissimilar: ('internally', -0.631)
#
# Word: shre
# Similar: [('##obbish', 0.1762), ('##sph', 0.1754), ('chroni', 0.1697)]
# Dissimilar: ('##mbib', -0.203)
#
# Word: shred
# Similar: [('readership', 0.7827), ('hedge', 0.7645), ('verse', 0.7638)]
# Dissimilar: ('oblige', -0.4252)
#
# Word: live
# Similar: [('walk', 0.912), ('stated', 0.8872), ('reacted', 0.8646)]
# Dissimilar: ('internally', -0.7613)
#
# Word: lives
# Similar: [('maze', 0.7701), ('awhile', 0.7608), ('essentially', 0.7596)]
# Dissimilar: ('dats', -0.5239)
#
# Word: accepte
# Similar: [('mixtur', 0.1977), ('dwe', 0.1872), ('##mith', 0.1818)]
# Dissimilar: ('slutty', -0.1804)
#
# Word: accepted
# Similar: [('awful', 0.8977), ('poo', 0.8875), ('suspicious', 0.8833)]
# Dissimilar: ('gently', -0.661)
#
# Word: ##ens
# Similar: [('##onabl', 0.1883), ('##emot', 0.1723), ('unsettl', 0.1596)]
# Dissimilar: ('maclai', -0.2375)
#
# Word: jens
# Similar: [('retirement', 0.4133), ('lovebox', 0.3876), ('consciously', 0.381)]
# Dissimilar: ('during', -0.2513)
#
# Word: sens
# Similar: [('smears', 0.1871), ('##apidly', 0.1702), ('smothe', 0.1643)]
# Dissimilar: ('##idu', -0.1866)
#
# Word: listens
# Similar: [('entertaining', 0.8856), ('conclusions', 0.8629), ('labels', 0.8617)]
# Dissimilar: ('internally', -0.6857)
#
# Word: tons
# Similar: [('workouts', 0.9008), ('sort', 0.8996), ('capable', 0.886)]
# Dissimilar: ('awards', -0.6475)
#
# Word: sense
# Similar: [('morsel', 0.8516), ('rooted', 0.8391), ('bunch', 0.8354)]
# Dissimilar: ('dats', -0.514)
#
# Word: ##er
# Similar: [('lifting', 0.708), ('bull', 0.6996), ('text', 0.6799)]
# Dissimilar: ('cynical', -0.4973)
#
# Word: matter
# Similar: [('directly', 0.8394), ('believe', 0.8284), ('acceptance', 0.8175)]
# Dissimilar: ('awards', -0.6597)
#
# Word: flower
# Similar: [('friendship', 0.7983), ('fake', 0.7897), ('cheese', 0.781)]
# Dissimilar: ('violence', -0.6012)
#
# Word: tender
# Similar: [('groggy', 0.8907), ('vulnerable', 0.8847), ('sympathetic', 0.8732)]
# Dissimilar: ('gently', -0.6652)
#
# Word: paper
# Similar: [('revamped', 0.9214), ('cuttings', 0.8952), ('tax', 0.8914)]
# Dissimilar: ('dats', -0.6631)
#
# Word: bother
# Similar: [('fuck', 0.9237), ('threaten', 0.9163), ('bless', 0.9046)]
# Dissimilar: ('internally', -0.6136)
#
# Word: younger
# Similar: [('job', 0.8458), ('bicycle', 0.8368), ('moisturizer', 0.8307)]
# Dissimilar: ('internally', -0.6115)
#
# Word: slower
# Similar: [('interpreted', 0.6665), ('mircowaved', 0.4915), ('permanently', 0.4748)]
# Dissimilar: ('entail', -0.2833)
#
# Word: employer
# Similar: [('pedestrian', 0.7754), ('stripped', 0.7663), ('mccarthy', 0.7454)]
# Dissimilar: ('violence', -0.4997)
#
# Word: sober
# Similar: [('disappoint', 0.8972), ('fuck', 0.8919), ('bless', 0.8915)]
# Dissimilar: ('internally', -0.661)
#
# Word: leader
# Similar: [('foot', 0.6484), ('pauses', 0.6369), ('testimony', 0.6243)]
# Dissimilar: ('nowhere', -0.3441)
#
# Word: teacher
# Similar: [('filter', 0.9511), ('rounds', 0.9483), ('mastery', 0.9444)]
# Dissimilar: ('gently', -0.6966)
#
# Word: follower
# Similar: [('drinks', 0.8412), ('box', 0.8405), ('race', 0.8348)]
# Dissimilar: ('gently', -0.5391)
#
# Word: shower
# Similar: [('spider', 0.8726), ('mouth', 0.8664), ('bias', 0.862)]
# Dissimilar: ('awards', -0.6666)
#
# Word: designer
# Similar: [('##llness', 0.813), ('bliss', 0.7889), ('hundreds', 0.7776)]
# Dissimilar: ('freakishly', -0.567)
#
# Word: wilder
# Similar: [('films', 0.5128), ('skeletal', 0.4516), ('wally', 0.4432)]
# Dissimilar: ('season', -0.3377)
#
# Word: number
# Similar: [('material', 0.8954), ('reality', 0.8785), ('streets', 0.8701)]
# Dissimilar: ('dats', -0.6496)
#
# Word: greater
# Similar: [('lurking', 0.7456), ('club', 0.7454), ('gatsby', 0.7385)]
# Dissimilar: ('violence', -0.547)
#
# Word: per
# Similar: [('cara', 0.5322), ('abusive', 0.4545), ('instructions', 0.4221)]
# Dissimilar: ('laid', -0.4474)
#
# Word: prayer
# Similar: [('treatment', 0.9055), ('touching', 0.9007), ('cramping', 0.8982)]
# Dissimilar: ('awards', -0.7311)
#
# Word: is
# Similar Words (with Cosine Similarity):
#   feels: 0.5238
#   isnt: 0.5237
#   wasnt: 0.5228
# Dissimilar Word: violence (Cosine Similarity: -0.3060)

# %% [markdown]
# ## Starting Task 3

# %% [markdown]
# ### Loading Vocabulary and Initialize Word2Vec Model

# %%
# Load vocabulary from file
vocab_file_path = "vocabulary_41.txt"
with open(vocab_file_path, "r", encoding="utf-8") as f:
    vocab = [line.strip() for line in f]  # Read and clean each line

# Create word-to-index and index-to-word mappings for easy lookup
word_to_idx = {word: idx for idx, word in enumerate(vocab)}
idx_to_word = {idx: word for word, idx in word_to_idx.items()}

# Define hyperparameters (embedding dimension must match Task 2 settings)
embedding_dim = 400  

# Initialize and load the pre-trained Word2Vec model
word2vec_model = Word2VecModel(len(vocab))
word2vec_model.load_state_dict(torch.load("word2vec_checkpoint.pth"))
word2vec_model.eval()  # Set model to evaluation mode (no gradient updates)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_34268\2819210421.py:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   word2vec_model.load_state_dict(torch.load("word2vec_checkpoint.pth"))
# Word2VecModel(
#   (embedding): Embedding(14000, 400)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (linear): Linear(in_features=400, out_features=14000, bias=True)
# )

# %% [markdown]
# ### Define Neural Language Model Dataset

# %%
from torch.utils.data import Dataset

class NeuralLMDataset(Dataset):
    """
    Custom Dataset for Neural Language Modeling.
    Converts a tokenized corpus into (context, target) pairs for training.
    """
    def __init__(self, corpus, word_to_idx, context_size=4):
        """
        Args:
            corpus (dict): Tokenized text data from tokenized_data.json
            word_to_idx (dict): Mapping from words to indices
            context_size (int): Number of words used as context for prediction
        """
        self.word_to_idx = word_to_idx
        self.context_size = context_size
        self.data = self.preprocess_data(corpus)

    def preprocess_data(self, corpus):
        """
        Process corpus into training pairs (context, target).
        Only includes words that exist in the vocabulary.
        """
        data = []
        for key in corpus:
            tokens = corpus[key]  # Get tokenized sentence
            for i in range(len(tokens) - self.context_size):
                context = tokens[i:i + self.context_size]  # Extract context window
                target = tokens[i + self.context_size]  # Next word to predict

                # Ensure all words exist in vocabulary before adding to dataset
                if all(word in self.word_to_idx for word in context + [target]):
                    context_indices = [self.word_to_idx[word] for word in context]
                    target_index = self.word_to_idx[target]
                    data.append((context_indices, target_index))
        return data

    def __len__(self):
        """Returns the total number of (context, target) pairs."""
        return len(self.data)

    def __getitem__(self, idx):
        """Fetches a single (context, target) pair as tensors."""
        context, target = self.data[idx]
        return torch.tensor(context, dtype=torch.long), torch.tensor(target, dtype=torch.long)

# %% [markdown]
# ### Define Neural Language Models

# %%
import torch.nn as nn

class NeuralLM1(nn.Module):
    """
    A simple feedforward Neural Language Model with one hidden layer.
    """
    def __init__(self, vocab_size, embedding_dim, context_size, hidden_dim=128):
        super().__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)  # Embedding layer
        self.fc1 = nn.Linear(context_size * embedding_dim, hidden_dim)  # Fully connected hidden layer
        self.fc2 = nn.Linear(hidden_dim, vocab_size)  # Output layer

    def forward(self, context):
        """
        Forward pass through the model.
        Args:
            context (Tensor): Input tensor containing word indices
        Returns:
            Tensor: Logits for each word in vocabulary
        """
        embedded = self.embeddings(context).view(context.shape[0], -1)  # Flatten embedding output
        hidden = torch.relu(self.fc1(embedded))  # Apply ReLU activation
        output = self.fc2(hidden)  # Output logits
        return output


class NeuralLM2(nn.Module):
    """
    A deeper Neural Language Model with two hidden layers and dropout for regularization.
    """
    def __init__(self, vocab_size, embedding_dim, context_size, hidden_dim=256):
        super().__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.fc1 = nn.Linear(context_size * embedding_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)  # Additional hidden layer
        self.fc3 = nn.Linear(hidden_dim, vocab_size)
        self.dropout = nn.Dropout(0.3)  # Dropout for regularization

    def forward(self, context):
        embedded = self.embeddings(context).view(context.shape[0], -1)
        hidden = torch.relu(self.fc1(embedded))
        hidden = self.dropout(torch.relu(self.fc2(hidden)))  # Apply dropout after activation
        output = self.fc3(hidden)
        return output


class NeuralLM3(nn.Module):
    """
    A more advanced Neural Language Model with batch normalization.
    """
    def __init__(self, vocab_size, embedding_dim, context_size, hidden_dim=512):
        super().__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.fc1 = nn.Linear(context_size * embedding_dim, hidden_dim)
        self.bn1 = nn.BatchNorm1d(hidden_dim)  # Batch normalization
        self.fc2 = nn.Linear(hidden_dim, vocab_size)

    def forward(self, context):
        embedded = self.embeddings(context).view(context.shape[0], -1)
        hidden = torch.relu(self.bn1(self.fc1(embedded)))  # Apply batch normalization
        output = self.fc2(hidden)
        return output

# %% [markdown]
# ### Training and Evaluation of Neural Language Models

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import json
import math
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split

# Load tokenized dataset
with open("tokenized_data.json", "r", encoding="utf-8") as f:
    corpus = json.load(f)

# Hyperparameters
context_size = 4
embedding_dim = 400
batch_size = 1024
epochs = 45
learning_rate = 0.002
train_ratio = 0.8  # 80% Train, 20% Validation

# Create dataset instance
dataset = NeuralLMDataset(corpus, word_to_idx, context_size)

# Split dataset into training and validation sets
train_size = int(train_ratio * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Training function with validation tracking
def train_neural_lm(model, train_loader, val_loader, criterion, optimizer, epochs=10):
    """
    Trains a neural language model and evaluates it on a validation set.

    Args:
        model (nn.Module): Neural Language Model.
        train_loader (DataLoader): Dataloader for training data.
        val_loader (DataLoader): Dataloader for validation data.
        criterion (nn.Module): Loss function (CrossEntropyLoss).
        optimizer (torch.optim): Optimizer (Adam).
        epochs (int): Number of training epochs.

    Returns:
        train_losses (list): Loss values for training set.
        val_losses (list): Loss values for validation set.
    """
    model.train()
    train_losses, val_losses = [], []

    for epoch in range(epochs):
        total_train_loss, total_val_loss = 0, 0

        # Training phase
        for context, target in train_loader:
            context, target = context.long(), target.long()

            optimizer.zero_grad()
            output = model(context)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()

            total_train_loss += loss.item()

        avg_train_loss = total_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        # Validation phase
        model.eval()
        with torch.no_grad():
            for context, target in val_loader:
                context, target = context.long(), target.long()
                output = model(context)
                loss = criterion(output, target)
                total_val_loss += loss.item()

        avg_val_loss = total_val_loss / len(val_loader)
        val_losses.append(avg_val_loss)

        print(f"Epoch [{epoch+1}/{epochs}] - Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")

    return train_losses, val_losses

# Initialize models
models = {
    "NeuralLM1": NeuralLM1(len(vocab), embedding_dim, context_size),
    "NeuralLM2": NeuralLM2(len(vocab), embedding_dim, context_size),
    "NeuralLM3": NeuralLM3(len(vocab), embedding_dim, context_size),
}

# Train all models and plot loss curves
plt.figure(figsize=(10, 5))
for name, model in models.items():
    print(f"Training {name}...")
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()
    train_losses, val_losses = train_neural_lm(model, train_loader, val_loader, criterion, optimizer, epochs)

    # Plot loss curves
    plt.plot(train_losses, label=f"{name} - Train")
    plt.plot(val_losses, linestyle="dashed", label=f"{name} - Val")

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Neural LM Training & Validation Loss")
plt.legend()
plt.show()

# Define functions for model evaluation
def compute_accuracy(model, dataloader):
    """
    Computes accuracy of the model on a given dataset.

    Args:
        model (nn.Module): Trained model.
        dataloader (DataLoader): DataLoader containing dataset.

    Returns:
        float: Accuracy of the model.
    """
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for context, target in dataloader:
            context, target = context.long(), target.long()
            output = model(context)
            _, predicted = torch.max(output, dim=1)
            correct += (predicted == target).sum().item()
            total += target.size(0)
    return correct / total

def compute_perplexity(model, dataloader, criterion):
    """
    Computes perplexity of the model on a given dataset.

    Args:
        model (nn.Module): Trained model.
        dataloader (DataLoader): DataLoader containing dataset.
        criterion (nn.Module): Loss function (CrossEntropyLoss).

    Returns:
        float: Perplexity score.
    """
    model.eval()
    total_loss, total_samples = 0, 0
    with torch.no_grad():
        for context, target in dataloader:
            context, target = context.long(), target.long()
            output = model(context)
            loss = criterion(output, target)
            total_loss += loss.item() * target.size(0)
            total_samples += target.size(0)

    avg_loss = total_loss / total_samples
    return math.exp(avg_loss)

# Evaluate models and store metrics
train_accs, val_accs = [], []
train_ppls, val_ppls = [], []

for name, model in models.items():
    print(f"Evaluating {name}...")

    train_acc = compute_accuracy(model, train_loader)
    val_acc = compute_accuracy(model, val_loader)
    
    train_ppl = compute_perplexity(model, train_loader, criterion)
    val_ppl = compute_perplexity(model, val_loader, criterion)

    train_accs.append(train_acc)
    val_accs.append(val_acc)
    train_ppls.append(train_ppl)
    val_ppls.append(val_ppl)

    print(f"{name} - Train Acc: {train_acc * 100:.2f}% | Val Acc: {val_acc * 100:.2f}%")
    print(f"{name} - Train PPL: {train_ppl:.2f} | Val PPL: {val_ppl:.2f}")

# Compute average metrics
avg_train_acc = sum(train_accs) / len(train_accs)
avg_val_acc = sum(val_accs) / len(val_accs)
avg_train_ppl = sum(train_ppls) / len(train_ppls)
avg_val_ppl = sum(val_ppls) / len(val_ppls)

# Print average metrics
print("\n===== Average Metrics Across Models =====")
print(f"Average Train Accuracy: {avg_train_acc * 100:.2f}%")
print(f"Average Validation Accuracy: {avg_val_acc * 100:.2f}%")
print(f"Average Train Perplexity: {avg_train_ppl:.2f}")
print(f"Average Validation Perplexity: {avg_val_ppl:.2f}")
# Out:
# Training NeuralLM1...
# Epoch [1/45] - Train Loss: 7.3229 | Val Loss: 6.2255
# Epoch [2/45] - Train Loss: 5.3618 | Val Loss: 5.9770
# Epoch [3/45] - Train Loss: 4.6411 | Val Loss: 6.0065
# Epoch [4/45] - Train Loss: 3.9950 | Val Loss: 6.2326
# Epoch [5/45] - Train Loss: 3.3097 | Val Loss: 6.6630
# Epoch [6/45] - Train Loss: 2.6289 | Val Loss: 7.1793
# Epoch [7/45] - Train Loss: 2.1003 | Val Loss: 7.5805
# Epoch [8/45] - Train Loss: 1.7138 | Val Loss: 7.9545
# Epoch [9/45] - Train Loss: 1.4023 | Val Loss: 8.3251
# Epoch [10/45] - Train Loss: 1.1625 | Val Loss: 8.6647
# Epoch [11/45] - Train Loss: 0.9618 | Val Loss: 8.9821
# Epoch [12/45] - Train Loss: 0.7928 | Val Loss: 9.3189
# Epoch [13/45] - Train Loss: 0.6707 | Val Loss: 9.6111
# Epoch [14/45] - Train Loss: 0.5657 | Val Loss: 9.9009
# Epoch [15/45] - Train Loss: 0.4831 | Val Loss: 10.1928
# Epoch [16/45] - Train Loss: 0.4121 | Val Loss: 10.4245
# Epoch [17/45] - Train Loss: 0.3695 | Val Loss: 10.6819
# Epoch [18/45] - Train Loss: 0.3308 | Val Loss: 10.8979
# Epoch [19/45] - Train Loss: 0.2974 | Val Loss: 11.0917
# Epoch [20/45] - Train Loss: 0.2719 | Val Loss: 11.3020
# Epoch [21/45] - Train Loss: 0.2545 | Val Loss: 11.4778
# Epoch [22/45] - Train Loss: 0.2414 | Val Loss: 11.6206
# Epoch [23/45] - Train Loss: 0.2304 | Val Loss: 11.7551
# Epoch [24/45] - Train Loss: 0.2211 | Val Loss: 11.8877
# Epoch [25/45] - Train Loss: 0.2162 | Val Loss: 12.0165
# Epoch [26/45] - Train Loss: 0.2043 | Val Loss: 12.1099
# Epoch [27/45] - Train Loss: 0.1983 | Val Loss: 12.2211
# Epoch [28/45] - Train Loss: 0.1988 | Val Loss: 12.3038
# Epoch [29/45] - Train Loss: 0.1977 | Val Loss: 12.3564
# Epoch [30/45] - Train Loss: 0.1999 | Val Loss: 12.4285
# Epoch [31/45] - Train Loss: 0.1981 | Val Loss: 12.5061
# Epoch [32/45] - Train Loss: 0.1945 | Val Loss: 12.5838
# Epoch [33/45] - Train Loss: 0.1899 | Val Loss: 12.6524
# Epoch [34/45] - Train Loss: 0.1821 | Val Loss: 12.7237
# Epoch [35/45] - Train Loss: 0.1813 | Val Loss: 12.7947
# Epoch [36/45] - Train Loss: 0.1811 | Val Loss: 12.8283
# Epoch [37/45] - Train Loss: 0.1838 | Val Loss: 12.8876
# Epoch [38/45] - Train Loss: 0.1863 | Val Loss: 12.9197
# Epoch [39/45] - Train Loss: 0.1802 | Val Loss: 12.9710
# Epoch [40/45] - Train Loss: 0.1755 | Val Loss: 13.0208
# Epoch [41/45] - Train Loss: 0.1762 | Val Loss: 13.0505
# Epoch [42/45] - Train Loss: 0.1721 | Val Loss: 13.1136
# Epoch [43/45] - Train Loss: 0.1724 | Val Loss: 13.1765
# Epoch [44/45] - Train Loss: 0.1745 | Val Loss: 13.1671
# Epoch [45/45] - Train Loss: 0.1732 | Val Loss: 13.2199
# Training NeuralLM2...
# Epoch [1/45] - Train Loss: 7.0790 | Val Loss: 6.1595
# Epoch [2/45] - Train Loss: 5.6494 | Val Loss: 5.9261
# Epoch [3/45] - Train Loss: 4.9874 | Val Loss: 5.8884
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 100
#      98 optimizer = optim.Adam(model.parameters(), lr=learning_rate)
#      99 criterion = nn.CrossEntropyLoss()
# --> 100 train_losses, val_losses = train_neural_lm(model, train_loader, val_loader, criterion, optimizer, epochs)
#     102 # Plot loss curves
#     103 plt.plot(train_losses, label=f"{name} - Train")
#
# Cell In[23], line 64, in train_neural_lm(model, train_loader, val_loader, criterion, optimizer, epochs)
#      62     loss = criterion(output, target)
#      63     loss.backward()
# ---> 64     optimizer.step()
#      66     total_train_loss += loss.item()
#      68 avg_train_loss = total_train_loss / len(train_loader)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\optim\optimizer.py:487, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     482         else:
#     483             raise RuntimeError(
#     484                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     485             )
# --> 487 out = func(*args, **kwargs)
#     488 self._optimizer_step_code()
#     490 # call optimizer step post hooks
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\optim\optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      89     torch.set_grad_enabled(self.defaults["differentiable"])
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#      93     torch._dynamo.graph_break()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\optim\adam.py:223, in Adam.step(self, closure)
#     211     beta1, beta2 = group["betas"]
#     213     has_complex = self._init_group(
#     214         group,
#     215         params_with_grad,
#    (...)
#     220         state_steps,
#     221     )
# --> 223     adam(
#     224         params_with_grad,
#     225         grads,
#     226         exp_avgs,
#     227         exp_avg_sqs,
#     228         max_exp_avg_sqs,
#     229         state_steps,
#     230         amsgrad=group["amsgrad"],
#     231         has_complex=has_complex,
#     232         beta1=beta1,
#     233         beta2=beta2,
#     234         lr=group["lr"],
#     235         weight_decay=group["weight_decay"],
#     236         eps=group["eps"],
#     237         maximize=group["maximize"],
#     238         foreach=group["foreach"],
#     239         capturable=group["capturable"],
#     240         differentiable=group["differentiable"],
#     241         fused=group["fused"],
#     242         grad_scale=getattr(self, "grad_scale", None),
#     243         found_inf=getattr(self, "found_inf", None),
#     244     )
#     246 return loss
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\optim\optimizer.py:154, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     152     return disabled_func(*args, **kwargs)
#     153 else:
# --> 154     return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\optim\adam.py:784, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     781 else:
#     782     func = _single_tensor_adam
# --> 784 func(
#     785     params,
#     786     grads,
#     787     exp_avgs,
#     788     exp_avg_sqs,
#     789     max_exp_avg_sqs,
#     790     state_steps,
#     791     amsgrad=amsgrad,
#     792     has_complex=has_complex,
#     793     beta1=beta1,
#     794     beta2=beta2,
#     795     lr=lr,
#     796     weight_decay=weight_decay,
#     797     eps=eps,
#     798     maximize=maximize,
#     799     capturable=capturable,
#     800     differentiable=differentiable,
#     801     grad_scale=grad_scale,
#     802     found_inf=found_inf,
#     803 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\optim\adam.py:430, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     428         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     429     else:
# --> 430         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     432     param.addcdiv_(exp_avg, denom, value=-step_size)
#     434 # Lastly, switch back to complex view
#
# KeyboardInterrupt:

# %% [markdown]
# ### Predict Next Tokens

# %%
def predict_next_tokens(model, sentence, word_to_idx, idx_to_word, context_size=4, top_k=1):
    model.eval()
    tokens = sentence.strip().split()  # Simple tokenization (split by space)
    
    # Ensure [UNK] token exists in vocabulary
    unk_token = "[UNK]"
    if unk_token not in word_to_idx:
        print("Warning: [UNK] token is missing from vocabulary!")
        return []
    
    # Ensure the sentence has at least 'context_size' words
    if len(tokens) < context_size:
        print(f"Skipping: '{sentence}' (not enough context words)")
        return []

    # Get the last 'context_size' tokens
    context = tokens[-context_size:]
    
    predicted_words = []
    
    for _ in range(3):  # Predict three tokens
        # Convert words to indices, using [UNK] if word is not found
        context_indices = [word_to_idx.get(word, word_to_idx[unk_token]) for word in context]
        context_tensor = torch.tensor(context_indices, dtype=torch.long).unsqueeze(0)
        
        output = model(context_tensor)  # Get predictions
        
        # Select the top prediction
        predicted_idx = torch.argmax(output, dim=1).item()
        predicted_word = idx_to_word.get(predicted_idx, unk_token)  # Handle missing index

        predicted_words.append(predicted_word)
        context.append(predicted_word)  # Update context with predicted word
        context.pop(0)  # Maintain context size

    return predicted_words

# Load test sentences
test_file = "sample_test.txt"
with open(test_file, "r", encoding="utf-8") as f:
    test_sentences = [line.strip() for line in f]

# Select a trained model (e.g., NeuralLM3 as it's the best-performing one)
best_model = models["NeuralLM1"]

# Make predictions for each sentence
predictions = {}
for sentence in test_sentences:
    predictions[sentence] = predict_next_tokens(best_model, sentence, word_to_idx, idx_to_word)

# Print results
for sentence, predicted in predictions.items():
    print(f"Input: {sentence}")
    print(f"Predicted: {' '.join(predicted)}\n")
# Out:
# Input: i felt like earlier this year i was starting to feel emotional that it
# Predicted: was all over
#
# Input: i do need constant reminders when i go through lulls in feeling submiss
# Predicted: and i feel
#
# Input: i was really feeling crappy even after my awesome
# Predicted: week of workouts
#
# Input: i finally realise the feeling of being hated and its after effects are
# Predicted: a big way
#
# Input: i am feeling unhappy and weird
# Predicted: about many people
